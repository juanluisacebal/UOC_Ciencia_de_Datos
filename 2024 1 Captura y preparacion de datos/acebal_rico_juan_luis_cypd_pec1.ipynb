# %% [markdown]
# # PEC 1: INTRODUCCIÓN A LOS DATOS

# %% [markdown]
# En esta práctica vamos a retomar el contacto con los datos y vamos a hacer un repaso con los formatos de datos más habituales.

# %% [markdown]
# **NOTA:**  Para cargar los ficheros de datos se recomienda que se guarden en la carpeta del google drive donde se está trabajando. Una vez guardados, se debe montar la unidad del drive para poder acceder y referenciar la ruta para cargar los datos.
#
# El código que permite cargar la unidad drive es:
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
#
# ```
#
# Alternativamente se puede trabajar con una copia guardada localmente y abrir el Notebook desde la terminal.

# %% [markdown]
# _Ejemplo:_

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import json
import pandas as pd


ruta =  ("/Users/juan/Desktop/A ESTUDIOS JUAN"
        "/UOC/2024 1 Captura y preparacion "
        "de datos/PEC 1 Enunciado")
#with open("/Users/juan/Desktop/A ESTUDIOS JUAN/UOC/2024 1 Captura y preparacion de datos/PEC 1 Enunciado/data/parques-eolicos_JSON.json") as file:
#with open("/content/drive/My Drive/.../fichero_datos.json") as file:
#    data=json.load(file)

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# **Muestra un ejemplo de cada uno de los siguientes tipos de datos y justifica el por qué. Los ejemplos tienen que ser de la página de datos abiertos del ayuntamiento de Barcelona (https://opendata-ajuntament.barcelona.cat/data/es/dataset)**
#
# 1. datos estructurados
# 2. datos semi-estructuradas
# 3. datos no estructurados
#
# > NOTA: No es necesario que se compartan los datasets junto con la entrega de la PEC, es suficiente con referenciarlos, hacer una captura del dataset o copiar algunas instancias del dataset.

# %% [markdown]
# _Respuesta:_

# %% [markdown]
# Dato estructurado: un csv por ejemplo https://opendata-ajuntament.barcelona.cat/data/es/dataset/xarxasoroll-equipsmonitor-instal que es la red de monitorizácion de ruido ambiental del ayuntamiento de Barcelona. Son filas y columnas y tiene una estructura clara.
#
# Dato semiestructurado: https://opendata-ajuntament.barcelona.cat/data/es/dataset/servei-cataleg-metadades-csw
# Es un formato XML, propio de estructuras jerarquicas de un dato semiestructurado.
#
# Dato no estructurado: https://opendata-ajuntament.barcelona.cat/data/es/dataset/carrers-pacificats-bici-bcn
#     Si bien es un sitio web con dataset, y de base, eso quiere decir que casi todos, o todos los datos seran semi o estructurados,
#     despues de buscar y buscar he decidido elegir este por varios motivos, aunque como he dicho, es dudoso poder elegir uno:
#         Su formato principal es ZIP, y tiene varios archivos en el interior, por tanto no esta organizado y si alguno de
#         sus archivos es estructurado, tampoco esta directamente accesible.

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# El formato JSON (JavaScript Object Notation) es un formato de texto sencillo para el intercambio de datos, ampliamente utilizado. En Python, la librería **json** permite abrir datos de este tipo, asignarlos a una variable y trabajar con ellos.
#
# La función **json.load()** permite parsear una cadena JSON y convertirla en un diccionario de Python.
#
# De forma inversa, si tenemos un objeto python, lo podemos convertir en una cadena JSON utilizando **json.dumps()**.
#
# Una vez cargado el JSON, éste puede ser visualizado manteniendo la identación propia del JSON para hacer más fácil su interpretación mediante la modificación de los argumentos de la función json.dumps()
#
# _Ejemplo:_
#
# ```
# import json
#
# #ejemplo_json es una cadena json
# parsed_json = json.loads(ejemplo_json)
# print(json.dumps(parsed_json, indent=4, sort_keys=True))
#
# ```
#
# _Ejemplo de leer un JSON desde un archivo de texto o archivo JSON._
#
#
# ```
# with open('nombre_archivo.json') as archivo_json:
#     parsed_json = json.load(archivo_json)
#
# ```

# %% [markdown]
# **En este ejercicio trabajaremos con el dataset parques-eolicos_JSON.json en lo referente a los parques eólicos de Castilla y León. Se pide:**
#
# 1. **Cargar** y **visualizar** correctamente indentado lo JSON.
# 2. Mostrar con código el **número de registros**, qué **campos** contiene y de qué **tipo** son.
# 3. Transformar el json a un **dataframe** ayudandote de la librería pandas, de forma que cada campo diferente sea una columna.
# 4. **Visualizar** las 5 primeras filas y obtener las **dimensiones del DataFrame**.
# 5. Guardar el dataframe generado **como csv**.
# 6. **Cargar el csv** guardado en su punto anterior.
# 7. **Visualizar** las 5 primeras filas y obtener las **dimensiones del DataFrame**.
# 8. Mantiene los **mismos campos** el **csv generado y lo json facilitado** en el enunciado? Pasa lo mismo con el **tipo de dato** que Pandas asocia a cada columna?
#
# Con los **datos del CSV** parques-eolicos_CSV.csv, responder:
#
# 9. **Cargar** y **visualizar** correctamente el CSV como Dataframe.
# 10. Coger el **Dataframe provinente del JSON** (apartado 3) y **eliminar todas las columnas que no sean 'nombre' y 'fecha_puesta_en_marcha'**.
# 11. Hacer un **merge del Dataframe provinente del CSV** para **añadirle la fecha de puesta en marcha en base al nombre** del parque.
# 12. Con este último Dataframe, **mostrar los detalles de los siguientes parques**:
#     - El que tiene más aerogeneradores.
#     - El que tiene más potencia instalada.
#     - El que tiene los aerogeneradores con más potencia unitaria.
#     - El último en entrar en servicio.

# %% [markdown]
# Pregunta 1:

# %%
def cargar_json(ruta: str) -> dict:
    """Cargar archivo JSON."""
    with open(ruta, 'r') as archivo_json:
        return json.load(archivo_json)

def mostrar_json_indentado(json_data: dict) -> None:
    """Mostrar JSON indentado."""
    print(json.dumps(json_data, indent=4, sort_keys=True))

# Ejecucion
json_data = cargar_json(ruta+
                        "/data/parques-eolicos_JSON.json")
mostrar_json_indentado(json_data)
# Out:
# [
#     {
#         "fecha_puesta_en_marcha": "2000-04-01",
#         "no": 1,
#         "no_aerogeneradores": 22.0,
#         "nombre": "ALDEAVIEJA",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 14520,
#         "provincia": "AV",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "St\u00aa. M\u00aa del Cubillo y Ojos Albos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2002-03-01",
#         "no": 2,
#         "no_aerogeneradores": 32.0,
#         "nombre": "ALTOS DE CARTAGENA",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 21120,
#         "provincia": "AV",
#         "tecnologia": "MADE",
#         "termino_municipal": "Las Navas del Marqu\u00e9s"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-04-01",
#         "no": 3,
#         "no_aerogeneradores": 4.0,
#         "nombre": "AMPLIACION CRUZ DE HIERRO",
#         "pot_unit_kw": 1650,
#         "potencia_total_kw": 6600,
#         "provincia": "AV",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Santa Mar\u00eda del Cubillo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2000-04-01",
#         "no": 4,
#         "no_aerogeneradores": 18.0,
#         "nombre": "AVILA",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 11880,
#         "provincia": "AV",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "\u00c1vila y Tornadizos de \u00c1vila"
#     },
#     {
#         "fecha_puesta_en_marcha": "2011-06-21",
#         "no": 5,
#         "no_aerogeneradores": 15.0,
#         "nombre": "CABEZA MESA",
#         "pot_unit_kw": 1800,
#         "potencia_total_kw": 29600,
#         "provincia": "AV",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "San Juan del Olmo, Mu\u00f1ana, Vadillo Sierra y Amavida"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-03-25",
#         "no": 6,
#         "no_aerogeneradores": 17.0,
#         "nombre": "COLLADILLO",
#         "pot_unit_kw": 1800,
#         "potencia_total_kw": 30600,
#         "provincia": "AV",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valdecasa, Narrillos del Rebollar y Balbarda"
#     },
#     {
#         "fecha_puesta_en_marcha": "2011-06-11",
#         "no": 7,
#         "no_aerogeneradores": 4.0,
#         "nombre": "EL RINCON",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 8000,
#         "provincia": "AV",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "San Juan del Olmo, Mu\u00f1ana, Balbarda y Valdecasa"
#     },
#     {
#         "fecha_puesta_en_marcha": "2000-04-01",
#         "no": 8,
#         "no_aerogeneradores": 22.0,
#         "nombre": "LA CRUZ DE HIERRO",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 14520,
#         "provincia": "AV",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Ojos Albos y St\u00aa Mar\u00eda del Cubillo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-03-27",
#         "no": 9,
#         "no_aerogeneradores": 25.0,
#         "nombre": "LANCHAL",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 21250,
#         "provincia": "AV",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Sotalvo y San Juan de la Nava"
#     },
#     {
#         "fecha_puesta_en_marcha": "2002-03-01",
#         "no": 10,
#         "no_aerogeneradores": 16.0,
#         "nombre": "NAVAS DEL MARQUES",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 10560,
#         "provincia": "AV",
#         "tecnologia": "MADE",
#         "termino_municipal": "Las Navas del Marqu\u00e9s"
#     },
#     {
#         "fecha_puesta_en_marcha": "2002-03-01",
#         "no": 11,
#         "no_aerogeneradores": 26.0,
#         "nombre": "NAVAZUELO",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 17160,
#         "provincia": "AV",
#         "tecnologia": "MADE",
#         "termino_municipal": "Las Navas del Marqu\u00e9s"
#     },
#     {
#         "fecha_puesta_en_marcha": "2000-04-01",
#         "no": 12,
#         "no_aerogeneradores": 22.0,
#         "nombre": "OJOS ALBOS",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 14520,
#         "provincia": "AV",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Ojos Albos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-03-27",
#         "no": 13,
#         "no_aerogeneradores": 27.0,
#         "nombre": "PUCHERUELO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 22950,
#         "provincia": "AV",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "San Juan de la Nava"
#     },
#     {
#         "fecha_puesta_en_marcha": "2011-09-30",
#         "no": 14,
#         "no_aerogeneradores": 19.0,
#         "nombre": "VALDIHUELO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 16150,
#         "provincia": "AV",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Urraca Miguel"
#     },
#     {
#         "fecha_puesta_en_marcha": "2006-01-01",
#         "no": 15,
#         "no_aerogeneradores": 25.0,
#         "nombre": "VALPARDO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 21250,
#         "provincia": "AV",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Navalperal de Pinares"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-12-22",
#         "no": 16,
#         "no_aerogeneradores": 25.0,
#         "nombre": "ALTO DE LA DEGOLLADA",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 50000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Castrojeriz"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-12-12",
#         "no": 17,
#         "no_aerogeneradores": 10.0,
#         "nombre": "AMPLIACION DE LOS LLANOS",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 20000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Hontoria de la Cantera"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-09-27",
#         "no": 18,
#         "no_aerogeneradores": 3.0,
#         "nombre": "AMPLIACION MONTEJO",
#         "pot_unit_kw": 2200,
#         "potencia_total_kw": 6600,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Valle de Valdebezana"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-11-30",
#         "no": 19,
#         "no_aerogeneradores": 31.0,
#         "nombre": "ARROYAL",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 46500,
#         "provincia": "BU",
#         "tecnologia": "GENERAL ELECTRIC",
#         "termino_municipal": "Alfoz de Quintanadue\u00f1as"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-09-24",
#         "no": 20,
#         "no_aerogeneradores": 12.0,
#         "nombre": "BALLESTAS",
#         "pot_unit_kw": 3465,
#         "potencia_total_kw": 41580,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Vallejera y Castrojeriz"
#     },
#     {
#         "fecha_puesta_en_marcha": "2011-11-22",
#         "no": 21,
#         "no_aerogeneradores": 20.0,
#         "nombre": "BRULLES",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 40000,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Villadiego y Las Hormazas"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-02-11",
#         "no": 22,
#         "no_aerogeneradores": 6.0,
#         "nombre": "BUREBA",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 12000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Reinoso, Briviesca y Galbarros"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-08-04",
#         "no": 23,
#         "no_aerogeneradores": 19.0,
#         "nombre": "CAMPANARIO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 38000,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Carcedo de Burgos y Revillarruz"
#     },
#     {
#         "fecha_puesta_en_marcha": "2008-05-02",
#         "no": 24,
#         "no_aerogeneradores": 10.0,
#         "nombre": "CANTIRUELA",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 15000,
#         "provincia": "BU",
#         "tecnologia": "ACCIONA",
#         "termino_municipal": "Valle de Sedano"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-12-18",
#         "no": 25,
#         "no_aerogeneradores": 21.0,
#         "nombre": "CERRO BLANCO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 42000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Galbarros, Briviesca y Salinillas de Bureba"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-09-30",
#         "no": 26,
#         "no_aerogeneradores": 25.0,
#         "nombre": "COGOLLOS II",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 50000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Cogollos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2002-03-01",
#         "no": 27,
#         "no_aerogeneradores": 8.0,
#         "nombre": "CORRAL NUEVO",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 5280,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Sargentes de la Lora"
#     },
#     {
#         "fecha_puesta_en_marcha": "2022-12-07",
#         "no": 28,
#         "no_aerogeneradores": 4.0,
#         "nombre": "DELMORO",
#         "pot_unit_kw": 3000,
#         "potencia_total_kw": 12000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Carde\u00f1adijo y Modubar de la Emparedada"
#     },
#     {
#         "fecha_puesta_en_marcha": "1999-11-01",
#         "no": 29,
#         "no_aerogeneradores": 23.0,
#         "nombre": "EL CANTO",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 15180,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valle de Manzanedo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2001-10-01",
#         "no": 30,
#         "no_aerogeneradores": 6.0,
#         "nombre": "AMPLIACION EL CANTO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 5100,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valle de Manzanedo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-07-27",
#         "no": 31,
#         "no_aerogeneradores": 14.0,
#         "nombre": "EL CARRIL",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 28000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Castrojeriz y Pedrosa del Pr\u00edncipe"
#     },
#     {
#         "fecha_puesta_en_marcha": "2000-02-01",
#         "no": 32,
#         "no_aerogeneradores": 30.0,
#         "nombre": "EL CERRO",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 19800,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valle de Sedano y Los Altos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2002-03-01",
#         "no": 33,
#         "no_aerogeneradores": 12.0,
#         "nombre": "AMPLIACION EL CERRO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 10200,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valle de Sedano y Los Altos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2008-11-20",
#         "no": 34,
#         "no_aerogeneradores": 9.0,
#         "nombre": "EL COTEREJON I",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 18000,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Merindad de Valdeporres"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-06-01",
#         "no": 35,
#         "no_aerogeneradores": 3.0,
#         "nombre": "EL COTEREJON II",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 6000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Merindad de Valdeporres"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-04-27",
#         "no": 36,
#         "no_aerogeneradores": 26.0,
#         "nombre": "EL GALLO",
#         "pot_unit_kw": 1900,
#         "potencia_total_kw": 49400,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Villaquir\u00e1n de los Infantes, Villaldemiro, Tamar\u00f3n y Los Balbases"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-04-01",
#         "no": 37,
#         "no_aerogeneradores": 40.0,
#         "nombre": "EL NAVAZO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 38550,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Pedrosa del Pr\u00edncipe (BU)"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-01-30",
#         "no": 38,
#         "no_aerogeneradores": 9.0,
#         "nombre": "EL NEGREDO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 18000,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Merindad de R\u00edo Ubierna"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-08-04",
#         "no": 39,
#         "no_aerogeneradores": 12.0,
#         "nombre": "EL NOGAL",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 24000,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Carcedo de Burgos y Carde\u00f1adijo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-08-20",
#         "no": 40,
#         "no_aerogeneradores": 16.0,
#         "nombre": "EL PARAMO",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 24000,
#         "provincia": "BU",
#         "tecnologia": "GENERAL ELECTRIC",
#         "termino_municipal": "Alfoz de Quintanadue\u00f1as"
#     },
#     {
#         "fecha_puesta_en_marcha": "2006-04-01",
#         "no": 41,
#         "no_aerogeneradores": 31.0,
#         "nombre": "EL PERUL",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 49600,
#         "provincia": "BU",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Urbel del Castillo y Villadiego"
#     },
#     {
#         "fecha_puesta_en_marcha": "2008-10-17",
#         "no": 42,
#         "no_aerogeneradores": 14.0,
#         "nombre": "EL SOMBRIO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 28000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Merindad del R\u00edo Ubierna y Hu\u00e9rmeces"
#     },
#     {
#         "fecha_puesta_en_marcha": "2011-03-30",
#         "no": 44,
#         "no_aerogeneradores": 29.0,
#         "nombre": "FUENTE SALADA",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 46400,
#         "provincia": "BU",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Castellanos de Castro y Sasam\u00f3n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-08-04",
#         "no": 45,
#         "no_aerogeneradores": 16.0,
#         "nombre": "FUENTE VAIN",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 32000,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Carcedo de Burgos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2006-01-01",
#         "no": 46,
#         "no_aerogeneradores": 35.0,
#         "nombre": "LA BRUJULA",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 29750,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Monasterio de Rodilla y Valle de las Navas"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-01-01",
#         "no": 47,
#         "no_aerogeneradores": 15.0,
#         "nombre": "LA CALDERA",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 22500,
#         "provincia": "BU",
#         "tecnologia": "GENERAL ELECTRIC",
#         "termino_municipal": "Villadiego"
#     },
#     {
#         "fecha_puesta_en_marcha": "2008-12-30",
#         "no": 48,
#         "no_aerogeneradores": 16.0,
#         "nombre": "LA CALZADA",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 30600,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Montorio"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-09-24",
#         "no": 49,
#         "no_aerogeneradores": 8.0,
#         "nombre": "LA CASETONA",
#         "pot_unit_kw": 3465,
#         "potencia_total_kw": 27720,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Vallejera y Castrojeriz"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-02-02",
#         "no": 50,
#         "no_aerogeneradores": 9.0,
#         "nombre": "LA COTERA",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 18000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Merindad de Valdeporres y Valle de Valdebezana"
#     },
#     {
#         "fecha_puesta_en_marcha": "2022-02-24",
#         "no": 51,
#         "no_aerogeneradores": 4.0,
#         "nombre": "LA HUESA",
#         "pot_unit_kw": 4500,
#         "potencia_total_kw": 18000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Tardajos, Isar, Las Quintanillas, Rab\u00e9 de las Calzadas, Frandov\u00ednez, Estepar y Hornillos del Camino"
#     },
#     {
#         "fecha_puesta_en_marcha": "2006-03-01",
#         "no": 52,
#         "no_aerogeneradores": 7.0,
#         "nombre": "LA LASTRA",
#         "pot_unit_kw": 1670,
#         "potencia_total_kw": 11690,
#         "provincia": "BU",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Hu\u00e9rmeces y Villadiego"
#     },
#     {
#         "fecha_puesta_en_marcha": "2022-11-18",
#         "no": 53,
#         "no_aerogeneradores": 13.0,
#         "nombre": "LA LOMA",
#         "pot_unit_kw": 2625,
#         "potencia_total_kw": 34000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valle de Santiba\u00f1ez"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-12-01",
#         "no": 54,
#         "no_aerogeneradores": 31.0,
#         "nombre": "LA LORA I",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 49600,
#         "provincia": "BU",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Valle de Valdelucio"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-12-01",
#         "no": 55,
#         "no_aerogeneradores": 31.0,
#         "nombre": "LA LORA II",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 49600,
#         "provincia": "BU",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Valle de Valdelucio"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-03-01",
#         "no": 56,
#         "no_aerogeneradores": 28.0,
#         "nombre": "LA MAGDALENA",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 23800,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Merindad de Valdeporres"
#     },
#     {
#         "fecha_puesta_en_marcha": "2000-06-22",
#         "no": 57,
#         "no_aerogeneradores": 15.0,
#         "nombre": "LA MESA",
#         "pot_unit_kw": 600,
#         "potencia_total_kw": 9000,
#         "provincia": "BU",
#         "tecnologia": "ENERCON",
#         "termino_municipal": "Los Altos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2005-11-01",
#         "no": 58,
#         "no_aerogeneradores": 22.0,
#         "nombre": "LA PE\u00d1UCA",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 33000,
#         "provincia": "BU",
#         "tecnologia": "NEG MICON",
#         "termino_municipal": "Merindad de Valdeporres y Merindad de Sotoscueva"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-12-01",
#         "no": 59,
#         "no_aerogeneradores": 27.0,
#         "nombre": "LA SIA",
#         "pot_unit_kw": 1100,
#         "potencia_total_kw": 29700,
#         "provincia": "BU",
#         "tecnologia": "MADE",
#         "termino_municipal": "Espinosa de los Monteros"
#     },
#     {
#         "fecha_puesta_en_marcha": "2006-01-01",
#         "no": 60,
#         "no_aerogeneradores": 17.0,
#         "nombre": "LA VELETA",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 14450,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Monasterio de Rodilla y Fresno de Rodilla"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-02-24",
#         "no": 61,
#         "no_aerogeneradores": 22.0,
#         "nombre": "LA ZARZUELA",
#         "pot_unit_kw": 1900,
#         "potencia_total_kw": 41800,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Los Balbases y Vallejera"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-08-04",
#         "no": 62,
#         "no_aerogeneradores": 9.0,
#         "nombre": "LAS FUENTES",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 18000,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Carcedo de Burgos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2001-10-01",
#         "no": 63,
#         "no_aerogeneradores": 41.0,
#         "nombre": "LAS MAZORRAS",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 28390,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Merindad de Valdivielso y Los Altos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-12-01",
#         "no": 64,
#         "no_aerogeneradores": 33.0,
#         "nombre": "LAS PARDAS",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 49500,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valle de Sedano"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-10-07",
#         "no": 65,
#         "no_aerogeneradores": null,
#         "nombre": "LAS VINAS-FUENTE BLANCA",
#         "pot_unit_kw": null,
#         "potencia_total_kw": 48395,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valle de Santib\u00e1\u00f1ez, Alfoz de Quintanadue\u00f1as y Merindad de R\u00edo Ubierna"
#     },
#     {
#         "fecha_puesta_en_marcha": "2005-12-01",
#         "no": 66,
#         "no_aerogeneradores": 21.0,
#         "nombre": "LLANOS DE SAN MARTIN",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 17850,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Sta. M\u00aa del Invierno, Quintanavides y Castil de Peones"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-03-01",
#         "no": 67,
#         "no_aerogeneradores": 33.0,
#         "nombre": "LODOSO",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 49500,
#         "provincia": "BU",
#         "tecnologia": "GENERAL ELECTRIC",
#         "termino_municipal": "Pedrosa de R\u00edo Urbel"
#     },
#     {
#         "fecha_puesta_en_marcha": "2016-09-28",
#         "no": 68,
#         "no_aerogeneradores": 15.0,
#         "nombre": "LOS AUSINES",
#         "pot_unit_kw": 1800,
#         "potencia_total_kw": 27000,
#         "provincia": "BU",
#         "tecnologia": "NEG MICON",
#         "termino_municipal": "Ibeas de Juarros y Los Ausines"
#     },
#     {
#         "fecha_puesta_en_marcha": "2005-11-01",
#         "no": 69,
#         "no_aerogeneradores": 24.0,
#         "nombre": "LOS CASTRIOS",
#         "pot_unit_kw": 1100,
#         "potencia_total_kw": 26400,
#         "provincia": "BU",
#         "tecnologia": "MADE",
#         "termino_municipal": "Espinosa de los Monteros"
#     },
#     {
#         "fecha_puesta_en_marcha": "2011-03-30",
#         "no": 70,
#         "no_aerogeneradores": 7.0,
#         "nombre": "LOS COLLADOS",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 11200,
#         "provincia": "BU",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Castrojeriz, Villasandino y Sasamon"
#     },
#     {
#         "fecha_puesta_en_marcha": "2011-12-28",
#         "no": 71,
#         "no_aerogeneradores": 19.0,
#         "nombre": "LOS LLANOS",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 38000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Hontoria de la Cantera, Revillarruz y Cogollos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2011-12-02",
#         "no": 72,
#         "no_aerogeneradores": 26.0,
#         "nombre": "LOS ZAPATEROS",
#         "pot_unit_kw": 1900,
#         "potencia_total_kw": 49400,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Los Balbases y Castrojeriz"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-01-01",
#         "no": 73,
#         "no_aerogeneradores": 33.0,
#         "nombre": "MARMELLAR",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 49500,
#         "provincia": "BU",
#         "tecnologia": "GENERAL ELECTRIC",
#         "termino_municipal": "Pedrosa del R\u00edo Urbel"
#     },
#     {
#         "fecha_puesta_en_marcha": "2006-08-01",
#         "no": 74,
#         "no_aerogeneradores": 16.0,
#         "nombre": "MONTEJO DE BRICIA",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 13600,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valle de Valdebezana"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-07-01",
#         "no": 75,
#         "no_aerogeneradores": 28.0,
#         "nombre": "MONTIJA",
#         "pot_unit_kw": 1100,
#         "potencia_total_kw": 30800,
#         "provincia": "BU",
#         "tecnologia": "MADE",
#         "termino_municipal": "Merindad de Montija"
#     },
#     {
#         "fecha_puesta_en_marcha": "2022-02-22",
#         "no": 76,
#         "no_aerogeneradores": 7.0,
#         "nombre": "ORBANEJA",
#         "pot_unit_kw": 4500,
#         "potencia_total_kw": 31500,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Las Quintanillas, Hornillos del Camino, Isar y Rab\u00e9 de las Calzadas"
#     },
#     {
#         "fecha_puesta_en_marcha": "2002-05-01",
#         "no": 77,
#         "no_aerogeneradores": 66.0,
#         "nombre": "PARAMO DE POZA I",
#         "pot_unit_kw": 750,
#         "potencia_total_kw": 48912,
#         "provincia": "BU",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Poza de la Sal"
#     },
#     {
#         "fecha_puesta_en_marcha": "2002-08-01",
#         "no": 78,
#         "no_aerogeneradores": 67.0,
#         "nombre": "PARAMO DE POZA II",
#         "pot_unit_kw": 750,
#         "potencia_total_kw": 48740,
#         "provincia": "BU",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Poza de la Sal"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-07-28",
#         "no": 79,
#         "no_aerogeneradores": 9.0,
#         "nombre": "PARAMO VEGA",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 18000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valle de Santib\u00e1\u00f1ez y Hu\u00e9rmeces"
#     },
#     {
#         "fecha_puesta_en_marcha": "2001-12-01",
#         "no": 80,
#         "no_aerogeneradores": 8.0,
#         "nombre": "PE\u00d1A OTERO",
#         "pot_unit_kw": 600,
#         "potencia_total_kw": 4800,
#         "provincia": "BU",
#         "tecnologia": "ENERCON",
#         "termino_municipal": "Los Altos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2021-10-22",
#         "no": 81,
#         "no_aerogeneradores": 10.0,
#         "nombre": "PERDIGUERA",
#         "pot_unit_kw": 2200,
#         "potencia_total_kw": 22000,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Estepar"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-12-07",
#         "no": 82,
#         "no_aerogeneradores": 10.0,
#         "nombre": "QUINTANILLA",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 20000,
#         "provincia": "BU",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Merindad de Rio Ubierna"
#     },
#     {
#         "fecha_puesta_en_marcha": "2020-12-09",
#         "no": 83,
#         "no_aerogeneradores": 3.0,
#         "nombre": "QUINTANILLA FASE II",
#         "pot_unit_kw": 3330,
#         "potencia_total_kw": 9990,
#         "provincia": "BU",
#         "tecnologia": "GENERAL ELECTRIC",
#         "termino_municipal": "Merindad del Rio Ubierna"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-05-10",
#         "no": 84,
#         "no_aerogeneradores": 1.0,
#         "nombre": "QUINTANILLA SOBRESIERRA",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 850,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Quintanilla Sobresierra"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-04-01",
#         "no": 85,
#         "no_aerogeneradores": 6.0,
#         "nombre": "RABINALDO",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 9000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Merindad del Rio Ubierna"
#     },
#     {
#         "fecha_puesta_en_marcha": "2006-01-01",
#         "no": 86,
#         "no_aerogeneradores": 8.0,
#         "nombre": "RODILLA",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 11400,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Monasterio de Rodilla"
#     },
#     {
#         "fecha_puesta_en_marcha": "2008-11-11",
#         "no": 87,
#         "no_aerogeneradores": 12.0,
#         "nombre": "SARGENTES",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 24000,
#         "provincia": "BU",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Sargentes de la Lora"
#     },
#     {
#         "fecha_puesta_en_marcha": "2006-11-01",
#         "no": 88,
#         "no_aerogeneradores": 25.0,
#         "nombre": "URBEL DEL CASTILLO II",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 50000,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Hu\u00e9rmeces, Urbel del Castillo y Montorio"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-04-01",
#         "no": 89,
#         "no_aerogeneradores": 9.0,
#         "nombre": "VALBONILLA",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 11100,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Castrojeriz"
#     },
#     {
#         "fecha_puesta_en_marcha": "2008-09-08",
#         "no": 90,
#         "no_aerogeneradores": 19.0,
#         "nombre": "VALBUENA",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 30400,
#         "provincia": "BU",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Villafranca - Montes de Oca y Cerrat\u00f3n de Juarros"
#     },
#     {
#         "fecha_puesta_en_marcha": "2022-03-09",
#         "no": 91,
#         "no_aerogeneradores": 5.0,
#         "nombre": "VALDELUGO",
#         "pot_unit_kw": 3600,
#         "potencia_total_kw": 18000,
#         "provincia": "BU",
#         "tecnologia": "GE",
#         "termino_municipal": "Estepar"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-01-01",
#         "no": 92,
#         "no_aerogeneradores": 37.0,
#         "nombre": "VALDEPORRES",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 31450,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Merindad de Valdeporres"
#     },
#     {
#         "fecha_puesta_en_marcha": "2021-08-31",
#         "no": 93,
#         "no_aerogeneradores": 3.0,
#         "nombre": "VALDESANTOS",
#         "pot_unit_kw": 4500,
#         "potencia_total_kw": 13500,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Rab\u00e9 de las Calzadas, Frandov\u00ednez, Cabia y Estepar"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-08-01",
#         "no": 94,
#         "no_aerogeneradores": 21.0,
#         "nombre": "VILLAMIEL",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 17850,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Villamiel de la Sierra y Villoruebo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-08-01",
#         "no": 95,
#         "no_aerogeneradores": 19.0,
#         "nombre": "VILLORUEBO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 16150,
#         "provincia": "BU",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Villoruebo y Palazuelos de la Sierra"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-12-01",
#         "no": 96,
#         "no_aerogeneradores": 3.0,
#         "nombre": "ANEXO A VALDELIN",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 6000,
#         "provincia": "LE",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Folgoso de la Ribera"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-01-21",
#         "no": 97,
#         "no_aerogeneradores": 11.0,
#         "nombre": "ARGAOSO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 22000,
#         "provincia": "LE",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Santa Colomba de Somoza y Torre del Bierzo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2008-10-21",
#         "no": 98,
#         "no_aerogeneradores": 20.0,
#         "nombre": "CERRO BECERRIL Y LUCILLO",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 32000,
#         "provincia": "LE",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "LUCILLO"
#     },
#     {
#         "fecha_puesta_en_marcha": "2008-09-04",
#         "no": 99,
#         "no_aerogeneradores": 27.0,
#         "nombre": "EL PEDRON",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 43200,
#         "provincia": "LE",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Lucillo y Santa Colomba de Somoza"
#     },
#     {
#         "fecha_puesta_en_marcha": "2023-11-06",
#         "no": 100,
#         "no_aerogeneradores": 1.0,
#         "nombre": "EL PUERTO I (EXPERIMENTAL)",
#         "pot_unit_kw": 5000,
#         "potencia_total_kw": 5000,
#         "provincia": "LE",
#         "tecnologia": "NORDEX",
#         "termino_municipal": "Villaman\u00edn"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-11-01",
#         "no": 101,
#         "no_aerogeneradores": 36.0,
#         "nombre": "EL REDONDAL",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 30600,
#         "provincia": "LE",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Castropodame, Molinaseca y Torre del Bierzo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-07-01",
#         "no": 102,
#         "no_aerogeneradores": 14.0,
#         "nombre": "ERA DEL PICO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 11900,
#         "provincia": "LE",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Castropodame y Molinaseca"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-12-04",
#         "no": 103,
#         "no_aerogeneradores": 9.0,
#         "nombre": "ESPINA",
#         "pot_unit_kw": 1800,
#         "potencia_total_kw": 16200,
#         "provincia": "LE",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Ig\u00fce\u00f1a, Villagat\u00f3n y Valdesamario"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-09-24",
#         "no": 104,
#         "no_aerogeneradores": 4.0,
#         "nombre": "LA CUEZA",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 8000,
#         "provincia": "LE",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Sahag\u00fan"
#     },
#     {
#         "fecha_puesta_en_marcha": "2008-07-04",
#         "no": 105,
#         "no_aerogeneradores": 28.0,
#         "nombre": "LA MALLADA",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 44800,
#         "provincia": "LE",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Lucillo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-03-01",
#         "no": 106,
#         "no_aerogeneradores": 55.0,
#         "nombre": "MANZANAL",
#         "pot_unit_kw": 750,
#         "potencia_total_kw": 41250,
#         "provincia": "LE",
#         "tecnologia": "NEG MICON",
#         "termino_municipal": "Torre del Bierzo, Villagat\u00f3n, Brazuelo y Sta. Coloma de Somoza"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-11-01",
#         "no": 107,
#         "no_aerogeneradores": 25.0,
#         "nombre": "PENA DEL GATO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 50000,
#         "provincia": "LE",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Torre del Bierzo, Ig\u00fce\u00f1a y Villagat\u00f3n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-09-24",
#         "no": 108,
#         "no_aerogeneradores": 17.0,
#         "nombre": "VALDECARRION",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 34000,
#         "provincia": "LE",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Sahag\u00fan"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-12-01",
#         "no": 109,
#         "no_aerogeneradores": 6.0,
#         "nombre": "VALDELACASA III",
#         "pot_unit_kw": 1800,
#         "potencia_total_kw": 10800,
#         "provincia": "LE",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Villagat\u00f3n y Quintana del Castillo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-12-01",
#         "no": 110,
#         "no_aerogeneradores": 9.0,
#         "nombre": "VALDELIN",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 18000,
#         "provincia": "LE",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Folgoso de la Ribera, Ig\u00fce\u00f1a y Torre del Bierzo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-09-24",
#         "no": 111,
#         "no_aerogeneradores": 23.0,
#         "nombre": "VALDEPERONDO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 46000,
#         "provincia": "LE",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Cea"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-12-17",
#         "no": 112,
#         "no_aerogeneradores": 12.0,
#         "nombre": "VALDESAMARIO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 24000,
#         "provincia": "LE",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Riello, Valdesamario y Villagat\u00f3n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-12-01",
#         "no": 113,
#         "no_aerogeneradores": 3.0,
#         "nombre": "ALCONADA",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 4500,
#         "provincia": "PA",
#         "tecnologia": "ACCIONA",
#         "termino_municipal": "Ampudia"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-04-27",
#         "no": 114,
#         "no_aerogeneradores": 2.0,
#         "nombre": "ALTO DEL POCILLO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 4000,
#         "provincia": "PA",
#         "tecnologia": "MTORRES",
#         "termino_municipal": "Monz\u00f3n de Campos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2017-05-05",
#         "no": 115,
#         "no_aerogeneradores": 1.0,
#         "nombre": "AMPLIACION BECERRIL",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 2000,
#         "provincia": "PA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Becerril de Campos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-04-01",
#         "no": 116,
#         "no_aerogeneradores": 14.0,
#         "nombre": "ANGOSTILLOS",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 28000,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Hornillos de Cerrato y Baltan\u00e1s"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-03-31",
#         "no": 117,
#         "no_aerogeneradores": 3.0,
#         "nombre": "BECERRIL",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 6000,
#         "provincia": "PA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Becerril de Campos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2022-10-31",
#         "no": 118,
#         "no_aerogeneradores": 9.0,
#         "nombre": "BECERRIL IIB",
#         "pot_unit_kw": 3450,
#         "potencia_total_kw": 31050,
#         "provincia": "PA",
#         "tecnologia": "GE",
#         "termino_municipal": "Villaumbrales"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-03-01",
#         "no": 119,
#         "no_aerogeneradores": 58.0,
#         "nombre": "CARRASQUILLO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 49300,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Astudillo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2022-06-07",
#         "no": 120,
#         "no_aerogeneradores": 10.0,
#         "nombre": "CELADA FUSION",
#         "pot_unit_kw": 4800,
#         "potencia_total_kw": 48000,
#         "provincia": "PA",
#         "tecnologia": "NORDEX",
#         "termino_municipal": "Baltan\u00e1s, Hornillos de Cerrato, Herrera de Valdecarros"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-11-01",
#         "no": 121,
#         "no_aerogeneradores": 17.0,
#         "nombre": "CELADA I",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 34000,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Hornillos de Cerrato, Torquemada y Herrera de Valdeca\u00f1as"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-11-01",
#         "no": 122,
#         "no_aerogeneradores": 13.0,
#         "nombre": "CELADA V",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 26000,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Herrera de Valdeca\u00f1as y Villah\u00e1n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-10-01",
#         "no": 123,
#         "no_aerogeneradores": 39.0,
#         "nombre": "CHAMBON",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 33150,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Astudillo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2011-04-13",
#         "no": 124,
#         "no_aerogeneradores": 25.0,
#         "nombre": "CRUZ DE CARRUTERO",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 40000,
#         "provincia": "PA",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Carde\u00f1osa de Volpejera, Villamuera de la Cueza, Villanueva de Rebollar"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-12-01",
#         "no": 125,
#         "no_aerogeneradores": 33.0,
#         "nombre": "CUESTA MA\u00d1ERA",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 49500,
#         "provincia": "PA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Ampudia"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-11-01",
#         "no": 126,
#         "no_aerogeneradores": 1.0,
#         "nombre": "DEHESA DE TABLARES",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 850,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Puebla de la Valdavia"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-12-21",
#         "no": 127,
#         "no_aerogeneradores": 25.0,
#         "nombre": "DEHESILLA I",
#         "pot_unit_kw": 1875,
#         "potencia_total_kw": 46875,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Ampudia"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-12-21",
#         "no": 128,
#         "no_aerogeneradores": 25.0,
#         "nombre": "DEHESILLA II",
#         "pot_unit_kw": 1875,
#         "potencia_total_kw": 46875,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Ampudia"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-12-01",
#         "no": 129,
#         "no_aerogeneradores": 2.0,
#         "nombre": "DOS PICOS",
#         "pot_unit_kw": 800,
#         "potencia_total_kw": 1600,
#         "provincia": "PA",
#         "tecnologia": "MADE",
#         "termino_municipal": "Magaz"
#     },
#     {
#         "fecha_puesta_en_marcha": "2006-04-01",
#         "no": 130,
#         "no_aerogeneradores": 4.0,
#         "nombre": "DUENAS",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 3400,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Due\u00f1as"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-09-01",
#         "no": 131,
#         "no_aerogeneradores": 16.0,
#         "nombre": "EL CASTRE",
#         "pot_unit_kw": 1670,
#         "potencia_total_kw": 26720,
#         "provincia": "PA",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Pedraza de Campos y Torremormoj\u00f3n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-11-01",
#         "no": 132,
#         "no_aerogeneradores": 11.0,
#         "nombre": "EL CUADRON",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 22000,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Hornillos de Cerrato, Torquemada"
#     },
#     {
#         "fecha_puesta_en_marcha": "2001-04-01",
#         "no": 133,
#         "no_aerogeneradores": 30.0,
#         "nombre": "EL PICAL",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 19800,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Barruelo de Santull\u00e1n y Bra\u00f1osera"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-03-16",
#         "no": 134,
#         "no_aerogeneradores": 3.0,
#         "nombre": "EL RASO",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 4500,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Fuentes de Valdepero"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-12-01",
#         "no": 135,
#         "no_aerogeneradores": 51.0,
#         "nombre": "EL TERUELO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 43350,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Melgar de Yuso, Villodr\u00e9 y Astudillo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2020-11-04",
#         "no": 136,
#         "no_aerogeneradores": 15.0,
#         "nombre": "ENCINEDO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 30000,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Hornillos de Cerrato y Torquemada"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-12-01",
#         "no": 137,
#         "no_aerogeneradores": 7.0,
#         "nombre": "ENCINILLAS",
#         "pot_unit_kw": 3340,
#         "potencia_total_kw": 23380,
#         "provincia": "PA",
#         "tecnologia": "GENERAL ELECTRIC",
#         "termino_municipal": "Paredes de Nava"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-12-21",
#         "no": 138,
#         "no_aerogeneradores": 25.0,
#         "nombre": "ESQUILEO I",
#         "pot_unit_kw": 1875,
#         "potencia_total_kw": 46875,
#         "provincia": "PA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Ampudia"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-03-01",
#         "no": 139,
#         "no_aerogeneradores": 6.0,
#         "nombre": "GRIJOTA",
#         "pot_unit_kw": 830,
#         "potencia_total_kw": 4980,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Monz\u00f3n de Campos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-11-01",
#         "no": 140,
#         "no_aerogeneradores": 13.0,
#         "nombre": "HORNILLOS",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 26000,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Hornillos de Cerrato y Baltan\u00e1s"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-03-29",
#         "no": 141,
#         "no_aerogeneradores": 1.0,
#         "nombre": "LA COTORRA",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 1500,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Fuentes de Valdepero"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-12-01",
#         "no": 142,
#         "no_aerogeneradores": 27.0,
#         "nombre": "LA MUNECA",
#         "pot_unit_kw": 1500,
#         "potencia_total_kw": 40500,
#         "provincia": "PA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Ampudia"
#     },
#     {
#         "fecha_puesta_en_marcha": "2002-11-01",
#         "no": 143,
#         "no_aerogeneradores": 1.0,
#         "nombre": "LA RUYA (EXPERIMENTAL)",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 1600,
#         "provincia": "PA",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Aguilar de Campoo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-04-27",
#         "no": 144,
#         "no_aerogeneradores": 4.0,
#         "nombre": "LAS CANTERAS",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 8000,
#         "provincia": "PA",
#         "tecnologia": "MTORRES",
#         "termino_municipal": "Monz\u00f3n de Campos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2020-11-04",
#         "no": 145,
#         "no_aerogeneradores": 11.0,
#         "nombre": "LAS TADEAS",
#         "pot_unit_kw": 3550,
#         "potencia_total_kw": 39050,
#         "provincia": "PA",
#         "tecnologia": "GAMESA",
# ...
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-11-19",
#         "no": 217,
#         "no_aerogeneradores": 14.0,
#         "nombre": "EL POLEO",
#         "pot_unit_kw": 3465,
#         "potencia_total_kw": 48510,
#         "provincia": "VA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Castromonte y Valverde de Campos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2022-12-14",
#         "no": 218,
#         "no_aerogeneradores": 2.0,
#         "nombre": "LA SERNA",
#         "pot_unit_kw": 4900,
#         "potencia_total_kw": 9800,
#         "provincia": "VA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Cigu\u00f1uela y Zarat\u00e1n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-11-19",
#         "no": 219,
#         "no_aerogeneradores": 13.0,
#         "nombre": "LAS PANADERAS",
#         "pot_unit_kw": 3465,
#         "potencia_total_kw": 45045,
#         "provincia": "VA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Castromonte, Valverde de Campos y La Mudarra"
#     },
#     {
#         "fecha_puesta_en_marcha": "2013-07-24",
#         "no": 220,
#         "no_aerogeneradores": 6.0,
#         "nombre": "LAS TRAPERAS",
#         "pot_unit_kw": 1650,
#         "potencia_total_kw": 9900,
#         "provincia": "VA",
#         "tecnologia": "MTORRES",
#         "termino_municipal": "Medina del Campo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2020-11-27",
#         "no": 221,
#         "no_aerogeneradores": 8.0,
#         "nombre": "MIRABEL",
#         "pot_unit_kw": 3300,
#         "potencia_total_kw": 26400,
#         "provincia": "VA",
#         "tecnologia": "ACCIONA",
#         "termino_municipal": "Valverde de Campos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-12-13",
#         "no": 222,
#         "no_aerogeneradores": 12.0,
#         "nombre": "NAVILLAS",
#         "pot_unit_kw": 3465,
#         "potencia_total_kw": 41580,
#         "provincia": "VA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "La Mudarra, Valdenebro de los Valles, Valladolid y Villalba de los Alcores"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-10-26",
#         "no": 223,
#         "no_aerogeneradores": 30.0,
#         "nombre": "PENAFLOR III",
#         "pot_unit_kw": 1670,
#         "potencia_total_kw": 48990,
#         "provincia": "VA",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Pe\u00f1aflor de Hornija, Castromonte y La Mudarra"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-10-26",
#         "no": 224,
#         "no_aerogeneradores": 30.0,
#         "nombre": "PENAFLOR IV",
#         "pot_unit_kw": 1670,
#         "potencia_total_kw": 48990,
#         "provincia": "VA",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Pe\u00f1aflor de Hornija"
#     },
#     {
#         "fecha_puesta_en_marcha": "2020-06-02",
#         "no": 225,
#         "no_aerogeneradores": 12.0,
#         "nombre": "SAN BLAS",
#         "pot_unit_kw": 3300,
#         "potencia_total_kw": 39600,
#         "provincia": "VA",
#         "tecnologia": "ACCIONA",
#         "termino_municipal": "Castromonte,Valverde de Campos, Valdenebro de los Valles y La Mudarra"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-10-01",
#         "no": 226,
#         "no_aerogeneradores": 26.0,
#         "nombre": "SAN LORENZO A",
#         "pot_unit_kw": 1875,
#         "potencia_total_kw": 48750,
#         "provincia": "VA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Torrelobat\u00f3n, Torrecilla de la Torre, Barruelo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-12-01",
#         "no": 227,
#         "no_aerogeneradores": 21.0,
#         "nombre": "SAN LORENZO B",
#         "pot_unit_kw": 1875,
#         "potencia_total_kw": 39375,
#         "provincia": "VA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Torrelobat\u00f3n, San Pelayo, Pe\u00f1aflor de Hornija, Torrecilla de la Torre, Castromonte y Barruelo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-12-23",
#         "no": 228,
#         "no_aerogeneradores": 15.0,
#         "nombre": "SAN LORENZO C",
#         "pot_unit_kw": 1875,
#         "potencia_total_kw": 28125,
#         "provincia": "VA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Castromonte, Pe\u00f1aflor de Hornija y Torrelobat\u00f3n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-12-23",
#         "no": 229,
#         "no_aerogeneradores": 18.0,
#         "nombre": "SAN LORENZO D",
#         "pot_unit_kw": 1875,
#         "potencia_total_kw": 33750,
#         "provincia": "VA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Pe\u00f1aflor de Hornija"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-11-06",
#         "no": 230,
#         "no_aerogeneradores": 11.0,
#         "nombre": "TESO PARDO",
#         "pot_unit_kw": 3300,
#         "potencia_total_kw": 36300,
#         "provincia": "VA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Valverde de Campos y Castromonte"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-11-05",
#         "no": 231,
#         "no_aerogeneradores": 19.0,
#         "nombre": "TOROZOS A",
#         "pot_unit_kw": 2200,
#         "potencia_total_kw": 41800,
#         "provincia": "VA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Castromonte,Torrelobat\u00f3n, Torrecilla de la Torre y Barruelo"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-11-05",
#         "no": 232,
#         "no_aerogeneradores": 15.0,
#         "nombre": "TOROZOS B",
#         "pot_unit_kw": 2200,
#         "potencia_total_kw": 33000,
#         "provincia": "VA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Torrelobat\u00f3n, Berceruelo, Velilla y Villasexmir"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-11-05",
#         "no": 233,
#         "no_aerogeneradores": 18.0,
#         "nombre": "TOROZOS C",
#         "pot_unit_kw": 2200,
#         "potencia_total_kw": 39600,
#         "provincia": "VA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Torrelobat\u00f3n, Castrodeza, Berceruelo y Velliza"
#     },
#     {
#         "fecha_puesta_en_marcha": "2022-11-11",
#         "no": 234,
#         "no_aerogeneradores": 16.0,
#         "nombre": "TOROZOS II",
#         "pot_unit_kw": 2200,
#         "potencia_total_kw": 35200,
#         "provincia": "VA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Castromonte"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-10-01",
#         "no": 235,
#         "no_aerogeneradores": 1.0,
#         "nombre": "AEROGENERADOR EXPERIMENTAL I+D G-87",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 2000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-05-31",
#         "no": 236,
#         "no_aerogeneradores": 1.0,
#         "nombre": "AEROGENERADOR EXPERIMENTAL I+D G-90",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 2000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2002-10-22",
#         "no": 237,
#         "no_aerogeneradores": 28.0,
#         "nombre": "AMPLIACION A EL AGUALLAL",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 24950,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n y P\u00edas"
#     },
#     {
#         "fecha_puesta_en_marcha": "2002-10-01",
#         "no": 238,
#         "no_aerogeneradores": 35.0,
#         "nombre": "AMPLIACION LA GAMONEDA",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 29750,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n y Hermisende"
#     },
#     {
#         "fecha_puesta_en_marcha": "2019-12-19",
#         "no": 239,
#         "no_aerogeneradores": 12.0,
#         "nombre": "AMPLIACION DEL HIERRO",
#         "pot_unit_kw": 3600,
#         "potencia_total_kw": 43200,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Losacio, Losacino, Carbajales de Alba y Olmillos de Castro"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-06-04",
#         "no": 240,
#         "no_aerogeneradores": 7.0,
#         "nombre": "AMPLIACION HEDROSO-ACIBEROS",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 14000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-07-28",
#         "no": 241,
#         "no_aerogeneradores": 9.0,
#         "nombre": "AMPLIACION PADORNELO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 18000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-11-01",
#         "no": 242,
#         "no_aerogeneradores": 6.0,
#         "nombre": "CINSEIRO",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 12000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n y Hermisende"
#     },
#     {
#         "fecha_puesta_en_marcha": "2001-07-02",
#         "no": 243,
#         "no_aerogeneradores": 18.0,
#         "nombre": "EL AGUALLAL",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 11880,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n y P\u00edas"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-04-14",
#         "no": 244,
#         "no_aerogeneradores": 14.0,
#         "nombre": "EL HIERRO",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 22400,
#         "provincia": "ZA",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Olmillos de Castro y Santa Eufemia del Barco"
#     },
#     {
#         "fecha_puesta_en_marcha": "2001-11-01",
#         "no": 245,
#         "no_aerogeneradores": 10.0,
#         "nombre": "EL SISTRAL",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 8500,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "P\u00edas"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-04-01",
#         "no": 246,
#         "no_aerogeneradores": 37.0,
#         "nombre": "HEDROSO-ACIBEROS",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 31450,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2001-05-30",
#         "no": 247,
#         "no_aerogeneradores": 30.0,
#         "nombre": "LA GAMONEDA",
#         "pot_unit_kw": 660,
#         "potencia_total_kw": 19800,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n y Hermisende"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-03-29",
#         "no": 248,
#         "no_aerogeneradores": 2.0,
#         "nombre": "LA VEGA I",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 5000,
#         "provincia": "ZA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Monfarracinos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2010-03-29",
#         "no": 249,
#         "no_aerogeneradores": 2.0,
#         "nombre": "LA VEGA II",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 5000,
#         "provincia": "ZA",
#         "tecnologia": "VESTAS",
#         "termino_municipal": "Monfarracinos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-11-01",
#         "no": 250,
#         "no_aerogeneradores": 43.0,
#         "nombre": "LABRADAS FUSIONADO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 36550,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Villaferrue\u00f1a, Arrabalde, Alcubilla de Nogales y Villageriz"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-11-01",
#         "no": 251,
#         "no_aerogeneradores": 25.0,
#         "nombre": "LUBIAN",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 50000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-01-07",
#         "no": 252,
#         "no_aerogeneradores": 14.0,
#         "nombre": "MONTAMARTA",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 22400,
#         "provincia": "ZA",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Montamarta, Palacios del Pan y Andav\u00edas"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-07-01",
#         "no": 253,
#         "no_aerogeneradores": 53.0,
#         "nombre": "NEREA",
#         "pot_unit_kw": 750,
#         "potencia_total_kw": 39750,
#         "provincia": "ZA",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Requejo y Pedralba de la Prader\u00eda"
#     },
#     {
#         "fecha_puesta_en_marcha": "2004-04-01",
#         "no": 254,
#         "no_aerogeneradores": 37.0,
#         "nombre": "PADORNELO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 31450,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n"
#     },
#     {
#         "fecha_puesta_en_marcha": "2011-11-24",
#         "no": 255,
#         "no_aerogeneradores": 10.0,
#         "nombre": "PENA NEBINA",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 20000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Ferreruela y Olmillos de Castro"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-04-14",
#         "no": 256,
#         "no_aerogeneradores": 22.0,
#         "nombre": "PENARROLDANA",
#         "pot_unit_kw": 1600,
#         "potencia_total_kw": 35200,
#         "provincia": "ZA",
#         "tecnologia": "ECOTECNIA",
#         "termino_municipal": "Santa Eufemia del Barco"
#     },
#     {
#         "fecha_puesta_en_marcha": "2001-12-01",
#         "no": 257,
#         "no_aerogeneradores": 21.0,
#         "nombre": "SAN CIPRIAN",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 17850,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Lubi\u00e1n y Hermisende"
#     },
#     {
#         "fecha_puesta_en_marcha": "2009-01-14",
#         "no": 258,
#         "no_aerogeneradores": 20.0,
#         "nombre": "SIERRA DE LAS CARBAS",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 40000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Ferreruela"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-09-26",
#         "no": 259,
#         "no_aerogeneradores": 10.0,
#         "nombre": "SIERRA SESNANDEZ",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 20000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Ferreruela y Riofr\u00edo de Aliste"
#     },
#     {
#         "fecha_puesta_en_marcha": "2012-09-21",
#         "no": 260,
#         "no_aerogeneradores": 5.0,
#         "nombre": "VALDELANAVE",
#         "pot_unit_kw": 2000,
#         "potencia_total_kw": 10000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Muelas del Pan"
#     },
#     {
#         "fecha_puesta_en_marcha": "2003-05-01",
#         "no": 261,
#         "no_aerogeneradores": 40.0,
#         "nombre": "VALMEDIANO",
#         "pot_unit_kw": 850,
#         "potencia_total_kw": 34000,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "T\u00e1bara y Faramontanos de T\u00e1bara"
#     },
#     {
#         "fecha_puesta_en_marcha": "2007-06-07",
#         "no": 262,
#         "no_aerogeneradores": 6.0,
#         "nombre": "VILLALAZAN",
#         "pot_unit_kw": 830,
#         "potencia_total_kw": 4980,
#         "provincia": "ZA",
#         "tecnologia": "GAMESA",
#         "termino_municipal": "Toro, Villalaz\u00e1n y Madridanos"
#     },
#     {
#         "fecha_puesta_en_marcha": "2024-05-03",
#         "no": 263,
#         "no_aerogeneradores": 10.0,
#         "nombre": "ANDELLA",
#         "pot_unit_kw": 5000,
#         "potencia_total_kw": 50000,
#         "provincia": "VA",
#         "tecnologia": "SIEMENS GAMESA",
#         "termino_municipal": "Adalia, Mota del Marqu\u00e9s, Villasexmir y Torrelobat\u00f3n"
#     }
# ]

# %% [markdown]
# Pregunta 2:

# %%
def obtener_informacion_registros(json_data: dict) -> None:
    """Mostrar numero de registros y tipos de datos."""
    num_registros = len(json_data)
    campos_y_tipos = {clave: type(valor) for clave, valor in json_data[0].items()}
    
    print(f"Numero de registros: {num_registros}")
    print("Campos y tipos:", campos_y_tipos, '\n')

# Ejecucion
obtener_informacion_registros(json_data)
# Out:
# Numero de registros: 261
# Campos y tipos: {'no': <class 'int'>, 'nombre': <class 'str'>, 'termino_municipal': <class 'str'>, 'provincia': <class 'str'>, 'potencia_total_kw': <class 'int'>, 'tecnologia': <class 'str'>, 'no_aerogeneradores': <class 'float'>, 'pot_unit_kw': <class 'int'>, 'fecha_puesta_en_marcha': <class 'str'>}

# %% [markdown]
# Pregunta 3:

# %%
def json_a_dataframe(json_data: dict) -> pd.DataFrame:
    """Convertir JSON a DataFrame."""
    return pd.DataFrame(json_data)

# Ejecucion
df_parques = json_a_dataframe(json_data)

# %% [markdown]
# Pregunta 4:

# %%
def visualizar_dataframe(nombre_df: str, df: pd.DataFrame) -> None:
    """Mostrar las 5 primeras filas y dimensiones."""
    print(f"Primeras filas de {nombre_df}:\n")
    print(df.head())
    print("\n\n\n")
    print(f"Dimensiones de {nombre_df}: {df.shape}")

# Ejecucion
visualizar_dataframe("df_parques",df_parques)
# Out:
# Primeras filas de df_parques:
#
#    no                     nombre  \
# 0   1                 ALDEAVIEJA
# 1   2         ALTOS DE CARTAGENA
# 2   3  AMPLIACION CRUZ DE HIERRO
# 3   4                      AVILA
# 4   5                CABEZA MESA
#
#                                    termino_municipal provincia  \
# 0                   Stª. Mª del Cubillo y Ojos Albos        AV
# 1                              Las Navas del Marqués        AV
# 2                            Santa María del Cubillo        AV
# 3                        Ávila y Tornadizos de Ávila        AV
# 4  San Juan del Olmo, Muñana, Vadillo Sierra y Am...        AV
#
#    potencia_total_kw tecnologia  no_aerogeneradores  pot_unit_kw  \
# 0              14520     GAMESA                22.0        660.0
# 1              21120       MADE                32.0        660.0
# 2               6600     GAMESA                 4.0       1650.0
# 3              11880     GAMESA                18.0        660.0
# 4              29600     VESTAS                15.0       1800.0
#
#   fecha_puesta_en_marcha
# 0             2000-04-01
# 1             2002-03-01
# 2             2004-04-01
# 3             2000-04-01
# 4             2011-06-21
#
#
#
#
# Dimensiones de df_parques: (261, 9)

# %% [markdown]
# Pregunta 5:

# %%
def guardar_dataframe_csv(df: pd.DataFrame, nombre_archivo: str) -> None:
    """Guardar DataFrame como CSV."""
    df.to_csv(nombre_archivo, index=False)

# Ejecucion
guardar_dataframe_csv(df_parques, ruta+'/parques-eolicos_mi_CSV.csv')

# %% [markdown]
# Pregunta 6:

# %%
def cargar_csv(ruta: str, encoding: str) -> pd.DataFrame:
    """Carga un CSV."""
    return pd.read_csv(ruta, encoding=encoding)


# Ejecucion
df_parques_csv = cargar_csv(ruta+'/parques-eolicos_mi_CSV.csv', "utf-8")

# %% [markdown]
# Pregunta 7:

# %%
# Reutilizo funcion de Ejercicio 4 para visualizarlo
visualizar_dataframe("df_parques_csv",df_parques_csv)
# Out:
# Primeras filas de df_parques_csv:
#
#    no                     nombre  \
# 0   1                 ALDEAVIEJA
# 1   2         ALTOS DE CARTAGENA
# 2   3  AMPLIACION CRUZ DE HIERRO
# 3   4                      AVILA
# 4   5                CABEZA MESA
#
#                                    termino_municipal provincia  \
# 0                   Stª. Mª del Cubillo y Ojos Albos        AV
# 1                              Las Navas del Marqués        AV
# 2                            Santa María del Cubillo        AV
# 3                        Ávila y Tornadizos de Ávila        AV
# 4  San Juan del Olmo, Muñana, Vadillo Sierra y Am...        AV
#
#    potencia_total_kw tecnologia  no_aerogeneradores  pot_unit_kw  \
# 0              14520     GAMESA                22.0        660.0
# 1              21120       MADE                32.0        660.0
# 2               6600     GAMESA                 4.0       1650.0
# 3              11880     GAMESA                18.0        660.0
# 4              29600     VESTAS                15.0       1800.0
#
#   fecha_puesta_en_marcha
# 0             2000-04-01
# 1             2002-03-01
# 2             2004-04-01
# 3             2000-04-01
# 4             2011-06-21
#
#
#
#
# Dimensiones de df_parques_csv: (261, 9)

# %% [markdown]
# Pregunta 8:

# %%
def comparar_campos_y_tipos(df_json: pd.DataFrame, df_csv: pd.DataFrame) -> None:
    """Compara campos y tipos entre JSON y CSV."""
    print("Columnas de datos en JSON:")
    print(df_json.columns)
    print("Columnas de datos en CSV:")
    print(df_csv.columns)
    print(f"\nSon los mismos campos? : {df_json.columns.equals(df_csv.columns)}")
    print("Tipos de datos en JSON:")
    print(df_json.dtypes)
    print("Tipos de datos en CSV:")
    print(df_csv.dtypes)
    print(f"\nSon los mismos tipos? : {df_json.dtypes.equals(df_csv.dtypes)}")

# Ejecucion
comparar_campos_y_tipos(df_parques, df_parques_csv)
# Out:
# Columnas de datos en JSON:
# Index(['no', 'nombre', 'termino_municipal', 'provincia', 'potencia_total_kw',
#        'tecnologia', 'no_aerogeneradores', 'pot_unit_kw',
#        'fecha_puesta_en_marcha'],
#       dtype='object')
# Columnas de datos en CSV:
# Index(['no', 'nombre', 'termino_municipal', 'provincia', 'potencia_total_kw',
#        'tecnologia', 'no_aerogeneradores', 'pot_unit_kw',
#        'fecha_puesta_en_marcha'],
#       dtype='object')
#
# Son los mismos campos? : True
# Tipos de datos en JSON:
# no                          int64
# nombre                     object
# termino_municipal          object
# provincia                  object
# potencia_total_kw           int64
# tecnologia                 object
# no_aerogeneradores        float64
# pot_unit_kw               float64
# fecha_puesta_en_marcha     object
# dtype: object
# Tipos de datos en CSV:
# no                          int64
# nombre                     object
# termino_municipal          object
# provincia                  object
# potencia_total_kw           int64
# tecnologia                 object
# no_aerogeneradores        float64
# pot_unit_kw               float64
# fecha_puesta_en_marcha     object
# dtype: object
#
# Son los mismos tipos? : True

# %% [markdown]
# Pregunta 9:

# %%
# Reutilizo funcion del ejercicio 4 para visualizarlo y 6 para cargarlo
df_parques_csv = cargar_csv(ruta+'/data/parques-eolicos_CSV.csv', "utf-8")
visualizar_dataframe("df_parques_csv",df_parques_csv)
# Out:
# Primeras filas de df_parques_csv:
#
#    Num                     nombre  \
# 0    1                 ALDEAVIEJA
# 1    2         ALTOS DE CARTAGENA
# 2    3  AMPLIACION CRUZ DE HIERRO
# 3    4                      AVILA
# 4    5                CABEZA MESA
#
#                                              termino provincia  potencia  \
# 0                 StÂª. MÂª del Cubillo y Ojos Albos        AV     14520
# 1                             Las Navas del MarquÃ©s        AV     21120
# 2                           Santa MarÃ­a del Cubillo        AV      6600
# 3                      Ãvila y Tornadizos de Ãvila        AV     11880
# 4  San Juan del Olmo, MuÃ±ana, Vadillo Sierra y A...        AV     29600
#
#   tecnologia  Num AEROGENERADORES  POT. UNIT. (kW)
# 0     GAMESA                 22.0            660.0
# 1       MADE                 32.0            660.0
# 2     GAMESA                  4.0           1650.0
# 3     GAMESA                 18.0            660.0
# 4     VESTAS                 15.0           1800.0
#
#
#
#
# Dimensiones de df_parques_csv: (261, 8)

# %% [markdown]
# Pregunta 10:

# %%
def eliminar_columnas(df: pd.DataFrame, columnas_a_conservar: list) -> pd.DataFrame:
    """Elimina columnas que no se necesitan."""
    return df[columnas_a_conservar]

# Ejecucion
df_reducido = eliminar_columnas(df_parques, ['nombre', 'fecha_puesta_en_marcha'])
visualizar_dataframe("df_reducido",df_reducido)
# Out:
# Primeras filas de df_reducido:
#
#                       nombre fecha_puesta_en_marcha
# 0                 ALDEAVIEJA             2000-04-01
# 1         ALTOS DE CARTAGENA             2002-03-01
# 2  AMPLIACION CRUZ DE HIERRO             2004-04-01
# 3                      AVILA             2000-04-01
# 4                CABEZA MESA             2011-06-21
#
#
#
#
# Dimensiones de df_reducido: (261, 2)

# %% [markdown]
# Pregunta 11:

# %%
def hacer_merge(df_csv: pd.DataFrame, df_json: pd.DataFrame, clave: str) -> pd.DataFrame:
    """Hace merge de dos DataFrames."""
    return pd.merge(df_csv, df_json, on=clave, how='left')


df_merge = hacer_merge(cargar_csv(ruta+'/data/parques-eolicos_CSV.csv', "utf-8")
    , df_reducido, 'nombre')
visualizar_dataframe("df_merge",df_merge)
# Out:
# Primeras filas de df_merge:
#
#    Num                     nombre  \
# 0    1                 ALDEAVIEJA
# 1    2         ALTOS DE CARTAGENA
# 2    3  AMPLIACION CRUZ DE HIERRO
# 3    4                      AVILA
# 4    5                CABEZA MESA
#
#                                              termino provincia  potencia  \
# 0                 StÂª. MÂª del Cubillo y Ojos Albos        AV     14520
# 1                             Las Navas del MarquÃ©s        AV     21120
# 2                           Santa MarÃ­a del Cubillo        AV      6600
# 3                      Ãvila y Tornadizos de Ãvila        AV     11880
# 4  San Juan del Olmo, MuÃ±ana, Vadillo Sierra y A...        AV     29600
#
#   tecnologia  Num AEROGENERADORES  POT. UNIT. (kW) fecha_puesta_en_marcha
# 0     GAMESA                 22.0            660.0             2000-04-01
# 1       MADE                 32.0            660.0             2002-03-01
# 2     GAMESA                  4.0           1650.0             2004-04-01
# 3     GAMESA                 18.0            660.0             2000-04-01
# 4     VESTAS                 15.0           1800.0             2011-06-21
#
#
#
#
# Dimensiones de df_merge: (261, 9)

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Num                     261 non-null    int64
#  1   nombre                  261 non-null    object
#  2   termino                 261 non-null    object
#  3   provincia               261 non-null    object
#  4   potencia                261 non-null    int64
#  5   tecnologia              261 non-null    object
#  6   Num AEROGENERADORES     260 non-null    float64
#  7   POT. UNIT. (kW)         260 non-null    float64
#  8   fecha_puesta_en_marcha  257 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 18.5+ KB

# %% [markdown]
# Pregunta 12:

# %%
def parque_maximo(df: pd.DataFrame, columna: str) -> pd.Series:
    """Obtiene el parque con el valor máximo en una columna específica."""
    if columna == "fecha_puesta_en_marcha":
        df[columna] = pd.to_datetime(df[columna])
        return df.loc[df[columna].idxmax()]  
    else:
        return df.loc[df[columna].astype(float).idxmax()] 

# Ejecucion
parque_aerogeneradores = parque_maximo(df_merge, 'Num AEROGENERADORES')
print("Parque con más aerogeneradores:\n", parque_aerogeneradores)

parque_potencia_instalada = parque_maximo(df_merge, 'potencia')
print("Parque con más potencia instalada:\n", parque_potencia_instalada)

parque_potencia_unitaria = parque_maximo(df_merge, 'POT. UNIT. (kW)')
print("Parque con más potencia unitaria:\n", parque_potencia_unitaria)

parque_ultimo_servicio = parque_maximo(df_merge, 'fecha_puesta_en_marcha')
print("Último parque en entrar en servicio:\n", parque_ultimo_servicio)
# Out:
# Parque con más aerogeneradores:
#  Num                                      78
# nombre                    PARAMO DE POZA II
# termino                      Poza de la Sal
# provincia                                BU
# potencia                              48740
# tecnologia                        ECOTECNIA
# Num AEROGENERADORES                    67.0
# POT. UNIT. (kW)                       750.0
# fecha_puesta_en_marcha           2002-08-01
# Name: 76, dtype: object
# Parque con más potencia instalada:
#  Num                                         16
# nombre                    ALTO DE LA DEGOLLADA
# termino                            Castrojeriz
# provincia                                   BU
# potencia                                 50000
# tecnologia                              GAMESA
# Num AEROGENERADORES                       25.0
# POT. UNIT. (kW)                         2000.0
# fecha_puesta_en_marcha              2010-12-22
# Name: 15, dtype: object
# Parque con más potencia unitaria:
#  Num                                              100
# nombre                    EL PUERTO I (EXPERIMENTAL)
# termino                                  VillamanÃ­n
# provincia                                         LE
# potencia                                        5000
# tecnologia                                    NORDEX
# Num AEROGENERADORES                              1.0
# POT. UNIT. (kW)                               5000.0
# fecha_puesta_en_marcha                    2023-11-06
# Name: 98, dtype: object
# Último parque en entrar en servicio:
#  Num                                                                     263
# nombre                                                              ANDELLA
# termino                   Adalia, Mota del MarquÃ©s, Villasexmir y Torre...
# provincia                                                                VA
# potencia                                                              50000
# tecnologia                                                   SIEMENS GAMESA
# Num AEROGENERADORES                                                    10.0
# POT. UNIT. (kW)                                                      5000.0
# fecha_puesta_en_marcha                                  2024-05-03 00:00:00
# Name: 260, dtype: object

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# En este ejercicio se trabaja con ficheros separados por comas (CSV). Con tal finalidad, se pide:
#
# PARTE 1:
#
# 1. **Cargar los csv** 2024_padro.csv y 2024_biblioteques.csv y **visualizar las primeras filas** de los dataframes.
# 2. Mostrar las **dimensiones** de los DataFrames
# 3. Mostrar el **tipo de dato** de cada columna de los dataframes.
#
# PARTE 2:
#
# 4. Crear un **diccionario a partir del dataframe del padrón**. Las claves de este diccionario tienen que ser el campo ‘barri’ (barrio). Los valores del diccionario tienen que ser al mismo tiempo otros diccionarios donde las claves sean los campos 'Dones' (Mujeres), 'Homes' (Hombres) y 'Total' y los valores, el valor que tenga cada campo mencionado.
# 5. Crear un **diccionario a partir del dataframe de las biliotecas**. Las claves de este diccionario tienen que ser el campo ‘Nom_Equipament’ (nombre equipamiento). Los valores del diccionario tienen que ser al mismo tiempo otros diccionarios donde las claves sean los campos 'Nom_Districte' (Nombre del distrito), 'Nom_Barri' (nombre del barrio) y 'Valor' (visitas a 2024 de las bibliotecas).
#
# PARTE 3:
#
# 6. **Crear un diccionario** que sea la combinación de los dos anteriores añadiendo un campo nuevo a cada biblioteca del diccionario de las bibliotecas. **Este nuevo campo se llamará ‘Padro’ y su valor será la información relativa al padrón que se corresponda con el barrio de la biblioteca**. En los casos donde no exista valor de padrón, asignar el valor de ‘N/A’. **Visualizar el diccionario resultante.**
# 7. **Coincide el valor de registros con el del número de instancias del DataFrame inicial de bibliotecas?**
# 8. **Cuántos hombres, mujeres y visitas están asignadas a la 'Biblioteca Clara'?**
# 9. Añadir al diccionario un **nuevo parámetro 'Ratio' por cada biblioteca que será el cálculo del parámetro 'Valor' dividido entre el padrón 'Total'. Visualizar el diccionario resultante.**
# 10. Del diccionario, crear un **Dataframe con dos columnas: Biblioteca y Ratio. Mostrar el DataFrame e interpretar la ratio.**
# 11. Hay una biblioteca que no tiene parámetro 'Ratio'. **¿Por qué? Investiga y explica qué está pasando.** **¡Pregunta necesaria para evaluar la parte 3!**

# %% [markdown]
# PARTE 1:

# %% [markdown]
# Pregunta 1:

# %%
def visualizar_primeras_filas(nombre:str, df: pd.DataFrame) -> None:
    """Muestra las primeras filas del DataFrame."""
    print(f"Primeras filas de {nombre}:\n", df.head())

# %%
df_padro = cargar_csv(ruta+"/data/2024_padro.csv", "latin1")
visualizar_primeras_filas("df_padro",df_padro)
# Out:
# Primeras filas de df_padro:
#    Data_Referencia  Codi_Districte Nom_Districte  Codi_Barri Nom_Barri  AEB  \
# 0      2024-01-01               1  Ciutat Vella           1  el Raval    1
# 1      2024-01-01               1  Ciutat Vella           1  el Raval    1
# 2      2024-01-01               1  Ciutat Vella           1  el Raval    1
# 3      2024-01-01               1  Ciutat Vella           1  el Raval    1
# 4      2024-01-01               1  Ciutat Vella           1  el Raval    2
#
#    Seccio_Censal  Valor  SEXE
# 0           1001    628     1
# 1           1001    681     2
# 2           1002    625     1
# 3           1002    657     2
# 4           1003   1663     1

# %%
df_bibliotecas = cargar_csv(ruta+"/data/2024_biblioteques.csv", "utf-8")
visualizar_primeras_filas("df_bibliotecas",df_bibliotecas)
# Out:
# Primeras filas de df_bibliotecas:
#      Any Indicador                                     Nom_Equipament   Valor  \
# 0  2024   Visites            Biblioteca Barceloneta - La Fraternitat   36427
# 1  2024   Visites                   Biblioteca Francesca Bonnemaison  135968
# 2  2024   Visites                      Biblioteca Gotic - Andreu Nin   55849
# 3  2024   Visites                   Biblioteca Sant Pau - Santa Creu  109357
# 4  2024   Visites  Biblioteca Esquerra de l'Eixample - Agusti Cen...  271719
#
#    Codi_Districte Nom_Districte  Codi_Barri  \
# 0               1  Ciutat Vella           3
# 1               1  Ciutat Vella           4
# 2               1  Ciutat Vella           2
# 3               1  Ciutat Vella           1
# 4               2      Eixample           9
#
#                               Nom_Barri
# 0                        la Barceloneta
# 1  Sant Pere Santa Caterina i la Ribera
# 2                        el Barri Gotic
# 3                              el Raval
# 4        la Nova Esquerra de l'Eixample

# %% [markdown]
# Pregunta 2:

# %%
def mostrar_dimensiones(nombre: str, df: pd.DataFrame) -> None:
    """Mostrar dimensiones del DataFrame."""
    print(f"Dimensiones de {nombre}: {df.shape} ")

# %%
mostrar_dimensiones("df_padro",df_padro)
# Out:
# Dimensiones de df_padro: (2136, 9)

# %%
mostrar_dimensiones("df_bibliotecas",df_bibliotecas)
# Out:
# Dimensiones de df_bibliotecas: (40, 8)

# %% [markdown]
# Pregunta 3:

# %%
def mostrar_tipos_columnas(df: pd.DataFrame) -> None:
    """Mostrar tipos de datos por columna."""
    print(df.dtypes)

# %%
mostrar_tipos_columnas(df_padro)
# Out:
# Data_Referencia    object
# Codi_Districte      int64
# Nom_Districte      object
# Codi_Barri          int64
# Nom_Barri          object
# AEB                 int64
# Seccio_Censal       int64
# Valor               int64
# SEXE                int64
# dtype: object

# %%
mostrar_tipos_columnas(df_bibliotecas)
# Out:
# Any                int64
# Indicador         object
# Nom_Equipament    object
# Valor              int64
# Codi_Districte     int64
# Nom_Districte     object
# Codi_Barri         int64
# Nom_Barri         object
# dtype: object

# %% [markdown]
# PARTE 2:

# %% [markdown]
# Pregunta 4:

# %%
from typing import Dict

def crear_diccionario_padro(df: pd.DataFrame) -> Dict[str, Dict[str, int]]:
    """Crear diccionario del padrón con barrios como claves."""
    
    diccionario_padro = {}
    
    agrupado = df.groupby(['Nom_Barri', 'SEXE'])['Valor'].sum().unstack(fill_value=0)
    
    for barrio, fila in agrupado.iterrows():
        diccionario_padro[barrio] = {
            'Dones': fila.get(1, 0),  # Asumiendo que 1 es mujeres
            'Homes': fila.get(2, 0),  # Asumiendo que 2 es hombres
            'Total': fila.sum()         # Sumar ambos para obtener el total
        }
    
    return diccionario_padro

# Crear el diccionario del padrón
diccionario_padro = crear_diccionario_padro(df_padro)
print(diccionario_padro)
# Out:
# {'Baro de Viver': {'Dones': 1344, 'Homes': 1268, 'Total': 2612}, 'Can Baro': {'Dones': 4997, 'Homes': 4528, 'Total': 9525}, 'Can Peguera': {'Dones': 1141, 'Homes': 1039, 'Total': 2180}, 'Canyelles': {'Dones': 3603, 'Homes': 3194, 'Total': 6797}, 'Ciutat Meridiana': {'Dones': 5668, 'Homes': 5422, 'Total': 11090}, 'Diagonal Mar i el Front Maritim del Poblenou': {'Dones': 6924, 'Homes': 6570, 'Total': 13494}, 'Horta': {'Dones': 16389, 'Homes': 14702, 'Total': 31091}, 'Hostafrancs': {'Dones': 8471, 'Homes': 7721, 'Total': 16192}, 'Montbau': {'Dones': 2873, 'Homes': 2413, 'Total': 5286}, 'Navas': {'Dones': 11882, 'Homes': 10529, 'Total': 22411}, 'Pedralbes': {'Dones': 6658, 'Homes': 5840, 'Total': 12498}, 'Porta': {'Dones': 16253, 'Homes': 15076, 'Total': 31329}, 'Provencals del Poblenou': {'Dones': 11158, 'Homes': 10354, 'Total': 21512}, 'Sagrada Familia': {'Dones': 28608, 'Homes': 24217, 'Total': 52825}, 'Sant Andreu': {'Dones': 30941, 'Homes': 27710, 'Total': 58651}, 'Sant Antoni': {'Dones': 20220, 'Homes': 18478, 'Total': 38698}, 'Sant Genis dels Agudells': {'Dones': 4138, 'Homes': 3628, 'Total': 7766}, 'Sant Gervasi - Galvany': {'Dones': 26408, 'Homes': 21990, 'Total': 48398}, 'Sant Gervasi - la Bonanova': {'Dones': 14535, 'Homes': 12215, 'Total': 26750}, 'Sant Marti de Provensals': {'Dones': 14103, 'Homes': 12472, 'Total': 26575}, 'Sant Pere Santa Caterina i la Ribera': {'Dones': 11368, 'Homes': 11105, 'Total': 22473}, 'Sants': {'Dones': 24223, 'Homes': 22840, 'Total': 47063}, 'Sants - Badal': {'Dones': 13289, 'Homes': 11642, 'Total': 24931}, 'Sarria\xa0': {'Dones': 13440, 'Homes': 11673, 'Total': 25113}, 'Torre Baro': {'Dones': 1577, 'Homes': 1542, 'Total': 3119}, 'Vallbona': {'Dones': 730, 'Homes': 707, 'Total': 1437}, 'Vallcarca i els Penitents': {'Dones': 8870, 'Homes': 7808, 'Total': 16678}, 'Vallvidrera el Tibidabo i les Planes': {'Dones': 2464, 'Homes': 2437, 'Total': 4901}, 'Verdun': {'Dones': 7103, 'Homes': 6091, 'Total': 13194}, 'Vilapicina i la Torre Llobeta': {'Dones': 14222, 'Homes': 12071, 'Total': 26293}, 'el Baix Guinardo': {'Dones': 14190, 'Homes': 12090, 'Total': 26280}, 'el Barri Gotic': {'Dones': 9901, 'Homes': 17321, 'Total': 27222}, 'el Besos i el Maresme': {'Dones': 14141, 'Homes': 16344, 'Total': 30485}, 'el Bon Pastor': {'Dones': 7773, 'Homes': 8025, 'Total': 15798}, "el Camp d'en Grassot i Gracia Nova": {'Dones': 19636, 'Homes': 16776, 'Total': 36412}, "el Camp de l'Arpa del Clot": {'Dones': 20734, 'Homes': 18326, 'Total': 39060}, 'el Carmel': {'Dones': 17318, 'Homes': 15719, 'Total': 33037}, 'el Clot': {'Dones': 14029, 'Homes': 12738, 'Total': 26767}, 'el Coll': {'Dones': 4253, 'Homes': 3690, 'Total': 7943}, 'el Congres i els Indians': {'Dones': 7875, 'Homes': 7070, 'Total': 14945}, 'el Fort Pienc': {'Dones': 18636, 'Homes': 17483, 'Total': 36119}, 'el Guinardo': {'Dones': 20292, 'Homes': 17861, 'Total': 38153}, 'el Parc i la Llacuna del Poblenou': {'Dones': 8843, 'Homes': 8196, 'Total': 17039}, 'el Poble Sec': {'Dones': 19902, 'Homes': 19275, 'Total': 39177}, 'el Poblenou': {'Dones': 17896, 'Homes': 16667, 'Total': 34563}, 'el Putxet i el Farro': {'Dones': 16491, 'Homes': 13844, 'Total': 30335}, 'el Raval': {'Dones': 22288, 'Homes': 24646, 'Total': 46934}, 'el Turo de la Peira': {'Dones': 8948, 'Homes': 7872, 'Total': 16820}, "l'Antiga Esquerra de l'Eixample": {'Dones': 23091, 'Homes': 20717, 'Total': 43808}, 'la Barceloneta': {'Dones': 7389, 'Homes': 7137, 'Total': 14526}, 'la Bordeta': {'Dones': 10740, 'Homes': 9652, 'Total': 20392}, 'la Clota': {'Dones': 411, 'Homes': 430, 'Total': 841}, "la Dreta de l'Eixample": {'Dones': 23939, 'Homes': 20948, 'Total': 44887}, "la Font d'en Fargues": {'Dones': 5163, 'Homes': 4674, 'Total': 9837}, 'la Font de la Guatlla': {'Dones': 5439, 'Homes': 5260, 'Total': 10699}, 'la Guineueta': {'Dones': 8250, 'Homes': 7123, 'Total': 15373}, 'la Marina de Port': {'Dones': 16164, 'Homes': 14796, 'Total': 30960}, 'la Marina del Prat Vermell': {'Dones': 983, 'Homes': 994, ' ...

# %% [markdown]
# Pregunta 5:

# %%
def crear_diccionario_bibliotecas(df: pd.DataFrame) -> Dict[str, Dict[str, str]]:
    """Diccionario de bibliotecas con nombre del lugar como clave."""
    diccionario_bibliotecas = {}
    for distrito, fila in df.iterrows():
        diccionario_bibliotecas[fila['Nom_Equipament']] = {
            'Nom_Districte': fila['Nom_Districte'],
            'Nom_Barri': fila['Nom_Barri'],
            'Valor': fila['Valor']
        }
    return diccionario_bibliotecas

# %%
# Crear diccionario de bibliotecas
diccionario_bibliotecas = crear_diccionario_bibliotecas(df_bibliotecas)
print(diccionario_bibliotecas)
# Out:
# {'Biblioteca Barceloneta - La Fraternitat': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'la Barceloneta', 'Valor': 36427}, 'Biblioteca Francesca Bonnemaison': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'Sant Pere Santa Caterina i la Ribera', 'Valor': 135968}, 'Biblioteca Gotic - Andreu Nin': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'el Barri Gotic', 'Valor': 55849}, 'Biblioteca Sant Pau - Santa Creu': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'el Raval', 'Valor': 109357}, "Biblioteca Esquerra de l'Eixample - Agusti Centelles": {'Nom_Districte': 'Eixample', 'Nom_Barri': "la Nova Esquerra de l'Eixample", 'Valor': 271719}, 'Biblioteca Fort Pienc': {'Nom_Districte': 'Eixample', 'Nom_Barri': 'el Fort Pienc', 'Valor': 100233}, 'Biblioteca Joan Miro': {'Nom_Districte': 'Eixample', 'Nom_Barri': "la Nova Esquerra de l'Eixample", 'Valor': 162696}, 'Biblioteca Sagrada Familia - J M Ainaud de Lasarte': {'Nom_Districte': 'Eixample', 'Nom_Barri': 'la Sagrada Familia', 'Valor': 79479}, 'Biblioteca Sant Antoni - Joan Oliver': {'Nom_Districte': 'Eixample', 'Nom_Barri': 'Sant Antoni', 'Valor': 148868}, 'Biblioteca Sofia Barat': {'Nom_Districte': 'Eixample', 'Nom_Barri': "la Dreta de l'Eixample", 'Valor': 42965}, 'Biblioteca Jaume Fuster': {'Nom_Districte': 'Gracia', 'Nom_Barri': 'Vallcarca i els Penitents', 'Valor': 388614}, 'Biblioteca Vallcarca i els Penitents - M Antonieta Cot': {'Nom_Districte': 'Gracia', 'Nom_Barri': 'Vallcarca i els Penitents', 'Valor': 44559}, 'Biblioteca Vila de Gracia': {'Nom_Districte': 'Gracia', 'Nom_Barri': 'la Vila de Gracia', 'Valor': 246383}, 'Biblioteca El Carmel - Juan Marse': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'el Carmel', 'Valor': 86868}, 'Biblioteca Guinardo - Merce Rodoreda': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'el Baix Guinardo', 'Valor': 183962}, 'Biblioteca Horta - Can Mariner': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'Horta', 'Valor': 94756}, 'Biblioteca Montbau - Albert Perez Baro': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'Montbau', 'Valor': 48582}, 'Biblioteca Les Corts - Miquel Llongueras': {'Nom_Districte': 'Les Corts', 'Nom_Barri': 'la Maternitat i Sant Ramon', 'Valor': 70867}, 'Biblioteca Montserrat Abello': {'Nom_Districte': 'Les Corts', 'Nom_Barri': 'les Corts', 'Valor': 298212}, 'Biblioteca Canyelles': {'Nom_Districte': 'Nou Barris', 'Nom_Barri': 'Canyelles', 'Valor': 13895}, 'Biblioteca Les Roquetes - Rafa Juncadella': {'Nom_Districte': 'Nou Barris', 'Nom_Barri': 'les Roquetes', 'Valor': 93760}, 'Biblioteca Nou Barris': {'Nom_Districte': 'Nou Barris', 'Nom_Barri': 'la Guineueta', 'Valor': 191288}, 'Biblioteca Vilapicina i la Torre Llobeta': {'Nom_Districte': 'Nou Barris', 'Nom_Barri': 'Vilapicina i la Torre Llobeta', 'Valor': 129543}, 'Biblioteca Zona Nord': {'Nom_Districte': 'Nou Barris', 'Nom_Barri': 'Torre Baro', 'Valor': 34522}, 'Biblioteca Bon Pastor': {'Nom_Districte': 'Sant Andreu', 'Nom_Barri': 'el Bon Pastor', 'Valor': 48889}, 'Biblioteca Ignasi Iglesias - Can Fabra': {'Nom_Districte': 'Sant Andreu', 'Nom_Barri': 'Sant Andreu', 'Valor': 371521}, 'Biblioteca La Sagrera - Marina Clotet': {'Nom_Districte': 'Sant Andreu', 'Nom_Barri': 'la Sagrera', 'Valor': 56294}, 'Biblioteca Trinitat Vella - Jose Barbero': {'Nom_Districte': 'Sant Andreu', 'Nom_Barri': 'la Trinitat Vella', 'Valor': 35823}, "Biblioteca Camp de l'Arpa - Caterina Albert": {'Nom_Districte': 'Sant Marti', 'Nom_Barri': "el Camp de l'Arpa del Clot", 'Valor': 136754}, 'Biblioteca El Clot - Josep Benet': {'Nom_Districte': 'Sant Marti', 'Nom_Barri': 'el Parc i la Llacuna del Poblenou', 'Valor': 132566}, 'Biblioteca Gabriel Garcia Marquez': {'Nom_Districte': 'Sant Marti', 'Nom_Barri': 'Sant Marti de Provensals', 'Valor': 157362}, 'Biblioteca Poblenou - Manuel Arranz': {'Nom_Districte': 'Sant Marti', 'Nom_Barri': 'el Poblenou', 'Valor': 138706}, "Biblioteca Ramon d'Alos-Moner": {'Nom_Districte': 'Sant Marti', 'Nom_Barri': 'el Besos i el Maresme', 'Valor': 23855}, 'Biblio ...

# %% [markdown]
# PARTE 3:

# %% [markdown]
# Pregunta 6:

# %%
def combinar_diccionarios(
    dic_bibliotecas: Dict[str, Dict[str, str]],
    dic_padro: Dict[str, Dict[str, int]]
) -> Dict[str, Dict[str, Dict]]:
    """Combinar diccionarios y añadir padrón."""
    for biblioteca, info in dic_bibliotecas.items():
        barrio = info['Nom_Barri']
        if barrio in dic_padro:
            dic_bibliotecas[biblioteca]['Padro'] = dic_padro[barrio]
        else:
            dic_bibliotecas[biblioteca]['Padro'] = 'N/A'
    return dic_bibliotecas

# %%
# Combono diccionarios
diccionario_combinado = combinar_diccionarios(diccionario_bibliotecas, diccionario_padro)
print(diccionario_combinado)
# Out:
# {'Biblioteca Barceloneta - La Fraternitat': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'la Barceloneta', 'Valor': 36427, 'Padro': {'Dones': 7389, 'Homes': 7137, 'Total': 14526}}, 'Biblioteca Francesca Bonnemaison': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'Sant Pere Santa Caterina i la Ribera', 'Valor': 135968, 'Padro': {'Dones': 11368, 'Homes': 11105, 'Total': 22473}}, 'Biblioteca Gotic - Andreu Nin': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'el Barri Gotic', 'Valor': 55849, 'Padro': {'Dones': 9901, 'Homes': 17321, 'Total': 27222}}, 'Biblioteca Sant Pau - Santa Creu': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'el Raval', 'Valor': 109357, 'Padro': {'Dones': 22288, 'Homes': 24646, 'Total': 46934}}, "Biblioteca Esquerra de l'Eixample - Agusti Centelles": {'Nom_Districte': 'Eixample', 'Nom_Barri': "la Nova Esquerra de l'Eixample", 'Valor': 271719, 'Padro': {'Dones': 31107, 'Homes': 27192, 'Total': 58299}}, 'Biblioteca Fort Pienc': {'Nom_Districte': 'Eixample', 'Nom_Barri': 'el Fort Pienc', 'Valor': 100233, 'Padro': {'Dones': 18636, 'Homes': 17483, 'Total': 36119}}, 'Biblioteca Joan Miro': {'Nom_Districte': 'Eixample', 'Nom_Barri': "la Nova Esquerra de l'Eixample", 'Valor': 162696, 'Padro': {'Dones': 31107, 'Homes': 27192, 'Total': 58299}}, 'Biblioteca Sagrada Familia - J M Ainaud de Lasarte': {'Nom_Districte': 'Eixample', 'Nom_Barri': 'la Sagrada Familia', 'Valor': 79479, 'Padro': 'N/A'}, 'Biblioteca Sant Antoni - Joan Oliver': {'Nom_Districte': 'Eixample', 'Nom_Barri': 'Sant Antoni', 'Valor': 148868, 'Padro': {'Dones': 20220, 'Homes': 18478, 'Total': 38698}}, 'Biblioteca Sofia Barat': {'Nom_Districte': 'Eixample', 'Nom_Barri': "la Dreta de l'Eixample", 'Valor': 42965, 'Padro': {'Dones': 23939, 'Homes': 20948, 'Total': 44887}}, 'Biblioteca Jaume Fuster': {'Nom_Districte': 'Gracia', 'Nom_Barri': 'Vallcarca i els Penitents', 'Valor': 388614, 'Padro': {'Dones': 8870, 'Homes': 7808, 'Total': 16678}}, 'Biblioteca Vallcarca i els Penitents - M Antonieta Cot': {'Nom_Districte': 'Gracia', 'Nom_Barri': 'Vallcarca i els Penitents', 'Valor': 44559, 'Padro': {'Dones': 8870, 'Homes': 7808, 'Total': 16678}}, 'Biblioteca Vila de Gracia': {'Nom_Districte': 'Gracia', 'Nom_Barri': 'la Vila de Gracia', 'Valor': 246383, 'Padro': {'Dones': 27766, 'Homes': 23309, 'Total': 51075}}, 'Biblioteca El Carmel - Juan Marse': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'el Carmel', 'Valor': 86868, 'Padro': {'Dones': 17318, 'Homes': 15719, 'Total': 33037}}, 'Biblioteca Guinardo - Merce Rodoreda': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'el Baix Guinardo', 'Valor': 183962, 'Padro': {'Dones': 14190, 'Homes': 12090, 'Total': 26280}}, 'Biblioteca Horta - Can Mariner': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'Horta', 'Valor': 94756, 'Padro': {'Dones': 16389, 'Homes': 14702, 'Total': 31091}}, 'Biblioteca Montbau - Albert Perez Baro': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'Montbau', 'Valor': 48582, 'Padro': {'Dones': 2873, 'Homes': 2413, 'Total': 5286}}, 'Biblioteca Les Corts - Miquel Llongueras': {'Nom_Districte': 'Les Corts', 'Nom_Barri': 'la Maternitat i Sant Ramon', 'Valor': 70867, 'Padro': {'Dones': 12962, 'Homes': 11351, 'Total': 24313}}, 'Biblioteca Montserrat Abello': {'Nom_Districte': 'Les Corts', 'Nom_Barri': 'les Corts', 'Valor': 298212, 'Padro': {'Dones': 25038, 'Homes': 21702, 'Total': 46740}}, 'Biblioteca Canyelles': {'Nom_Districte': 'Nou Barris', 'Nom_Barri': 'Canyelles', 'Valor': 13895, 'Padro': {'Dones': 3603, 'Homes': 3194, 'Total': 6797}}, 'Biblioteca Les Roquetes - Rafa Juncadella': {'Nom_Districte': 'Nou Barris', 'Nom_Barri': 'les Roquetes', 'Valor': 93760, 'Padro': {'Dones': 8794, 'Homes': 8147, 'Total': 16941}}, 'Biblioteca Nou Barris': {'Nom_Districte': 'Nou Barris', 'Nom_Barri': 'la Guineueta', 'Valor': 191288, 'Padro': {'Dones': 8250, 'Homes': 7123, 'Total': 15373}}, 'Biblioteca Vilapicina i la Torre Llobeta': {'Nom_Districte': 'Nou Barris', 'Nom_Barri': 'Vilapicina i la Torre Llobeta',  ...

# %% [markdown]
# Pregunta 7:

# %%
def verificar_registros(df: pd.DataFrame, dic: Dict[str, Dict]) -> bool:
    """Verificar si el número de registros coincide."""
    return len(df) == len(dic)

# vefifico coincidencia de registros
coinciden_registros = verificar_registros(df_bibliotecas, diccionario_combinado)
print(f"¿Coinciden los registros? {coinciden_registros}")
# Out:
# ¿Coinciden los registros? True

# %% [markdown]
# Pregunta 8:

# %%
def obtener_informacion_biblioteca(dic: Dict[str, Dict], nombre: str) -> Dict:
    """Obtener información de una biblioteca."""
    return dic.get(nombre, 'No encontrada')

# obtengo informacion de la 'Biblioteca Clara'
info_clara = obtener_informacion_biblioteca(diccionario_combinado, 'Biblioteca Clara')
print(info_clara)
# Out:
# {'Nom_Districte': 'Sarria-Sant Gervasi', 'Nom_Barri': 'les Tres Torres', 'Valor': 54173, 'Padro': {'Dones': 8678, 'Homes': 7715, 'Total': 16393}}

# %% [markdown]
# Pregunta 9:

# %%
def calcular_ratio(dic: Dict[str, Dict]) -> None:
    """Añadir campo 'Ratio' a cada biblioteca."""
    for biblioteca, info in dic.items():
        padro = info['Padro']
        if padro != 'N/A' and padro['Total'] > 0:
            dic[biblioteca]['Ratio'] = info['Valor'] / padro['Total']
        else:
            dic[biblioteca]['Ratio'] = 'N/A'

# Añadir campo ratio
calcular_ratio(diccionario_combinado)
print(diccionario_combinado)
# Out:
# {'Biblioteca Barceloneta - La Fraternitat': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'la Barceloneta', 'Valor': 36427, 'Padro': {'Dones': 7389, 'Homes': 7137, 'Total': 14526}, 'Ratio': 2.5077103125430265}, 'Biblioteca Francesca Bonnemaison': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'Sant Pere Santa Caterina i la Ribera', 'Valor': 135968, 'Padro': {'Dones': 11368, 'Homes': 11105, 'Total': 22473}, 'Ratio': 6.050282561295777}, 'Biblioteca Gotic - Andreu Nin': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'el Barri Gotic', 'Valor': 55849, 'Padro': {'Dones': 9901, 'Homes': 17321, 'Total': 27222}, 'Ratio': 2.051612666225847}, 'Biblioteca Sant Pau - Santa Creu': {'Nom_Districte': 'Ciutat Vella', 'Nom_Barri': 'el Raval', 'Valor': 109357, 'Padro': {'Dones': 22288, 'Homes': 24646, 'Total': 46934}, 'Ratio': 2.3300166190821154}, "Biblioteca Esquerra de l'Eixample - Agusti Centelles": {'Nom_Districte': 'Eixample', 'Nom_Barri': "la Nova Esquerra de l'Eixample", 'Valor': 271719, 'Padro': {'Dones': 31107, 'Homes': 27192, 'Total': 58299}, 'Ratio': 4.660783203828539}, 'Biblioteca Fort Pienc': {'Nom_Districte': 'Eixample', 'Nom_Barri': 'el Fort Pienc', 'Valor': 100233, 'Padro': {'Dones': 18636, 'Homes': 17483, 'Total': 36119}, 'Ratio': 2.775076829369584}, 'Biblioteca Joan Miro': {'Nom_Districte': 'Eixample', 'Nom_Barri': "la Nova Esquerra de l'Eixample", 'Valor': 162696, 'Padro': {'Dones': 31107, 'Homes': 27192, 'Total': 58299}, 'Ratio': 2.79071682190089}, 'Biblioteca Sagrada Familia - J M Ainaud de Lasarte': {'Nom_Districte': 'Eixample', 'Nom_Barri': 'la Sagrada Familia', 'Valor': 79479, 'Padro': 'N/A', 'Ratio': 'N/A'}, 'Biblioteca Sant Antoni - Joan Oliver': {'Nom_Districte': 'Eixample', 'Nom_Barri': 'Sant Antoni', 'Valor': 148868, 'Padro': {'Dones': 20220, 'Homes': 18478, 'Total': 38698}, 'Ratio': 3.846917153341258}, 'Biblioteca Sofia Barat': {'Nom_Districte': 'Eixample', 'Nom_Barri': "la Dreta de l'Eixample", 'Valor': 42965, 'Padro': {'Dones': 23939, 'Homes': 20948, 'Total': 44887}, 'Ratio': 0.9571813665426515}, 'Biblioteca Jaume Fuster': {'Nom_Districte': 'Gracia', 'Nom_Barri': 'Vallcarca i els Penitents', 'Valor': 388614, 'Padro': {'Dones': 8870, 'Homes': 7808, 'Total': 16678}, 'Ratio': 23.30099532318024}, 'Biblioteca Vallcarca i els Penitents - M Antonieta Cot': {'Nom_Districte': 'Gracia', 'Nom_Barri': 'Vallcarca i els Penitents', 'Valor': 44559, 'Padro': {'Dones': 8870, 'Homes': 7808, 'Total': 16678}, 'Ratio': 2.671723228204821}, 'Biblioteca Vila de Gracia': {'Nom_Districte': 'Gracia', 'Nom_Barri': 'la Vila de Gracia', 'Valor': 246383, 'Padro': {'Dones': 27766, 'Homes': 23309, 'Total': 51075}, 'Ratio': 4.823945178658835}, 'Biblioteca El Carmel - Juan Marse': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'el Carmel', 'Valor': 86868, 'Padro': {'Dones': 17318, 'Homes': 15719, 'Total': 33037}, 'Ratio': 2.62941550382904}, 'Biblioteca Guinardo - Merce Rodoreda': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'el Baix Guinardo', 'Valor': 183962, 'Padro': {'Dones': 14190, 'Homes': 12090, 'Total': 26280}, 'Ratio': 7.000076103500761}, 'Biblioteca Horta - Can Mariner': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'Horta', 'Valor': 94756, 'Padro': {'Dones': 16389, 'Homes': 14702, 'Total': 31091}, 'Ratio': 3.0476986909395003}, 'Biblioteca Montbau - Albert Perez Baro': {'Nom_Districte': 'Horta-Guinardo', 'Nom_Barri': 'Montbau', 'Valor': 48582, 'Padro': {'Dones': 2873, 'Homes': 2413, 'Total': 5286}, 'Ratio': 9.190692395005675}, 'Biblioteca Les Corts - Miquel Llongueras': {'Nom_Districte': 'Les Corts', 'Nom_Barri': 'la Maternitat i Sant Ramon', 'Valor': 70867, 'Padro': {'Dones': 12962, 'Homes': 11351, 'Total': 24313}, 'Ratio': 2.914778102249825}, 'Biblioteca Montserrat Abello': {'Nom_Districte': 'Les Corts', 'Nom_Barri': 'les Corts', 'Valor': 298212, 'Padro': {'Dones': 25038, 'Homes': 21702, 'Total': 46740}, 'Ratio': 6.380231065468549}, 'Biblioteca Canyelles': {'Nom_Districte': 'Nou Barris', 'Nom_Barri': 'Canyelles', 'Valor': 13895 ...

# %% [markdown]
# Pregunta 10:

# %%
def crear_dataframe_ratio(dic: Dict[str, Dict]) -> pd.DataFrame:
    """Crear DataFrame con Biblioteca y Ratio."""
    datos = {'Biblioteca': [], 'Ratio': []}
    for biblioteca, info in dic.items():
        datos['Biblioteca'].append(biblioteca)
        datos['Ratio'].append(info['Ratio'])
    return pd.DataFrame(datos)

# DataFrame de Biblioteca y Ratio
df_ratio = crear_dataframe_ratio(diccionario_combinado)
print(df_ratio)
# Out:
#                                            Biblioteca      Ratio
# 0             Biblioteca Barceloneta - La Fraternitat    2.50771
# 1                    Biblioteca Francesca Bonnemaison   6.050283
# 2                       Biblioteca Gotic - Andreu Nin   2.051613
# 3                    Biblioteca Sant Pau - Santa Creu   2.330017
# 4   Biblioteca Esquerra de l'Eixample - Agusti Cen...   4.660783
# 5                               Biblioteca Fort Pienc   2.775077
# 6                                Biblioteca Joan Miro   2.790717
# 7   Biblioteca Sagrada Familia - J M Ainaud de Las...        N/A
# 8                Biblioteca Sant Antoni - Joan Oliver   3.846917
# 9                              Biblioteca Sofia Barat   0.957181
# 10                            Biblioteca Jaume Fuster  23.300995
# 11  Biblioteca Vallcarca i els Penitents - M Anton...   2.671723
# 12                          Biblioteca Vila de Gracia   4.823945
# 13                  Biblioteca El Carmel - Juan Marse   2.629416
# 14               Biblioteca Guinardo - Merce Rodoreda   7.000076
# 15                     Biblioteca Horta - Can Mariner   3.047699
# 16             Biblioteca Montbau - Albert Perez Baro   9.190692
# 17           Biblioteca Les Corts - Miquel Llongueras   2.914778
# 18                       Biblioteca Montserrat Abello   6.380231
# 19                               Biblioteca Canyelles   2.044284
# 20          Biblioteca Les Roquetes - Rafa Juncadella   5.534502
# 21                              Biblioteca Nou Barris  12.443115
# 22           Biblioteca Vilapicina i la Torre Llobeta   4.926901
# 23                               Biblioteca Zona Nord  11.068291
# 24                              Biblioteca Bon Pastor   3.094632
# 25             Biblioteca Ignasi Iglesias - Can Fabra   6.334436
# 26              Biblioteca La Sagrera - Marina Clotet   1.852264
# 27           Biblioteca Trinitat Vella - Jose Barbero   3.360191
# 28        Biblioteca Camp de l'Arpa - Caterina Albert   3.501126
# 29                   Biblioteca El Clot - Josep Benet   7.780151
# 30                  Biblioteca Gabriel Garcia Marquez    5.92143
# 31                Biblioteca Poblenou - Manuel Arranz   4.013135
# 32                      Biblioteca Ramon d'Alos-Moner   0.782516
# 33                        Biblioteca Xavier Benguerel   6.598121
# 34                         Biblioteca Francesc Candel   3.130652
# 35               Biblioteca Poble Sec - Francesc Boix   1.263701
# 36                              Biblioteca Vapor Vell   3.665512
# 37                                   Biblioteca Clara   3.304642
# 38              Biblioteca Collserola - Josep Miracle    2.49194
# 39            Biblioteca Sant Gervasi - Joan Maragall   6.147028

# %% [markdown]
# Pregunta 11:

# %%
def investigar_biblioteca_sin_ratio(dic: Dict[str, Dict]) -> None:
    """Investigar por qué una biblioteca no tiene ratio."""
    for biblioteca, info in dic.items():
        if info['Ratio'] == 'N/A':
            print(f"La biblioteca {biblioteca} no tiene ratio. Puede ser porque no hay datos de padrón o el total es 0.")
    print("Comprobacion hecha, si no hay ningun aviso, es que no hay ninguna biblioteca sin ratio")
            
investigar_biblioteca_sin_ratio(diccionario_combinado)
# Out:
# La biblioteca Biblioteca Sagrada Familia - J M Ainaud de Lasarte no tiene ratio. Puede ser porque no hay datos de padrón o el total es 0.
# Comprobacion hecha, si no hay ningun aviso, es que no hay ninguna biblioteca sin ratio

# %%
df_padro[df_padro['Nom_Barri'].str.contains("Sagrada Familia", case=False, na=False)]
# Out:
#     Data_Referencia  Codi_Districte Nom_Districte  Codi_Barri  \
# 148      2024-01-01               2      Eixample           6
# 149      2024-01-01               2      Eixample           6
# 150      2024-01-01               2      Eixample           6
# 151      2024-01-01               2      Eixample           6
# 152      2024-01-01               2      Eixample           6
# ..              ...             ...           ...         ...
# 211      2024-01-01               2      Eixample           6
# 212      2024-01-01               2      Eixample           6
# 213      2024-01-01               2      Eixample           6
# 214      2024-01-01               2      Eixample           6
# 215      2024-01-01               2      Eixample           6
#
#            Nom_Barri  AEB  Seccio_Censal  Valor  SEXE
# 148  Sagrada Familia   23           2021    803     1
# 149  Sagrada Familia   23           2021    726     2
# 150  Sagrada Familia   23           2022    696     1
# 151  Sagrada Familia   23           2022    649     2
# 152  Sagrada Familia   23           2023    575     1
# ..               ...  ...            ...    ...   ...
# 211  Sagrada Familia   27           2052    837     2
# 212  Sagrada Familia   27           2053   1008     1
# 213  Sagrada Familia   27           2053    891     2
# 214  Sagrada Familia   27           2054   1059     1
# 215  Sagrada Familia   27           2054    933     2
#
# [68 rows x 9 columns]

# %%
df_ratio[df_ratio['Biblioteca'].str.contains("Sagrada Familia", case=False, na=False)]
# Out:
#                                           Biblioteca Ratio
# 7  Biblioteca Sagrada Familia - J M Ainaud de Las...   N/A

# %%
df_bibliotecas[df_bibliotecas['Nom_Barri'].str.contains("Sagrada Familia", case=False, na=False)]
# Out:
#     Any Indicador                                     Nom_Equipament  Valor  \
# 7  2024   Visites  Biblioteca Sagrada Familia - J M Ainaud de Las...  79479
#
#    Codi_Districte Nom_Districte  Codi_Barri           Nom_Barri
# 7               2      Eixample           6  la Sagrada Familia

# %%
df_bibliotecas['Nom_Barri'] = df_bibliotecas['Nom_Barri'].replace("la Sagrada Familia", "Sagrada Familia")
diccionario_bibliotecas = crear_diccionario_bibliotecas(df_bibliotecas)
diccionario_combinado = combinar_diccionarios(diccionario_bibliotecas, diccionario_padro)
calcular_ratio(diccionario_combinado)

df_ratio = crear_dataframe_ratio(diccionario_combinado)

# %%
investigar_biblioteca_sin_ratio(diccionario_combinado)
# Out:
# Comprobacion hecha, si no hay ningun aviso, es que no hay ninguna biblioteca sin ratio

# %%
df_ratio[df_ratio['Biblioteca'].str.contains("Sagrada Familia", case=False, na=False)]
# Out:
#                                           Biblioteca     Ratio
# 7  Biblioteca Sagrada Familia - J M Ainaud de Las...  1.504572

# %%
# conclusion, faltaba hacer match en el campo Nom_Barri por la falta del articulo 'la'
investigar_biblioteca_sin_ratio(diccionario_combinado)
# Out:
# Comprobacion hecha, si no hay ningun aviso, es que no hay ninguna biblioteca sin ratio

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# Existen diferentes repositorios o páginas web que permiten el acceso a múltiples datasets con finalidades académicas o de consulta ciudadana. Posibles fuentes abiertas de información podrían ser las siguientes:
#
# - OpenData de ayuntamientos:
#     - Valencia (https://valencia.opendatasoft.com/pages/home/)
#     - Madrid (https://datos.madrid.es/portal/site/egob)
#     - Barcelona (https://opendata-ajuntament.barcelona.cat/ca)
#     ...
# - https://datos.gob.es/es/
# - https://archive.ics.uci.edu/ml/datasets.php
# - https://www.kaggle.com/datasets
# - https://bigml.com/gallery/datasets
# - https://toolbox.google.com/datasetsearch
# ...
#
# **En esta actividad se pide que se exploren los repositorios facilitados anteriormente y se escoja un dataset que contenga al menos variables numéricas y categóricas.**
#
# **Se solicita:**
#
# 1. **Indicar cuál ha sido la motivación por la que se ha escogido el dataset. Esta cuestión es de respuesta obligatoria para evaluar la originalidad de la realización del ejercicio.**
# 3. **Describir el dataset.**
# 4. **Describir a qué se refieren las columnas que forman el dataset. ¿Que representan?**
# 5. **¿De qué tipo son cada una de las columnas o variables del dataset?**
# 6. **Cargar el dataset en un dataframe y revisar que los tipos de datos se hayan definido correctamente. Si no están bien definidos, cambiar el tipo de dato que corresponda**.
# 7. **Visualizar las primeras filas del dataframe**.
# 8. **Hacer una propuesta de anális o objetivo de análisis que se podria llevar a cabo con el dataset. ¿Que tipo de conclusiones podríamos obtener?**
#
#
# ---
# https://www.kaggle.com/datasets/thomasfranois/worlds-best-restaurants

# %% [markdown]
# - **Indicar cuál ha sido la motivación por la que se han escogido los dos datasets. Esta cuestión es de respuesta obligatoria para evaluar la originalidad de la realización del ejercicio**

# %% [markdown]
# _Respuesta:_ Me gusta comer, y qué mejor que un dataset con los mejores 50 restaurantes de cada año en el mundo. Ademas seguro que la mayoría son caros y me permite utliziar el dataset durante mucho tiempo
# https://www.kaggle.com/datasets/thomasfranois/worlds-best-restaurants

# %% [markdown]
# - **Describir el datatet**

# %% [markdown]
# _Respuesta:_ Tiene 7 columnas: fecha, ranking, restaurante, lugar, latitud, longitud, pais,...  y 1050 registros.

# %% [markdown]
# - **Describir a qué se refieren las columnas que forman el dataset.¿Que representan?**

# %% [markdown]
# _Respuesta:_ Representan cada restaurante nominado entre los 50 mejores restaurantes mundiales de cada año

# %% [markdown]
# - **De qué tipo son cada una de las columnas o variables del dataset?**

# %% [markdown]
# _Respuesta:_todas numérico y string pais y lugar

# %% [markdown]
# - **Cargar el dataframe y revisar que los tipos de datos se hayan definido correctamente.**

# %% [markdown]
# _Respuesta:_ cargo el df y después hago un describe

# %%
df = pd.read_csv('WorldsBestRestaurants.csv')

# %%
df.describe(include='all')
# Out:
#                year         rank restaurant location        country  \
# count   1050.000000  1050.000000       1050     1050           1050
# unique          NaN          NaN        257      135             42
# top             NaN          NaN   Mugaritz    Paris  United States
# freq            NaN          NaN         17      103            145
# mean    2012.142857    25.490476        NaN      NaN            NaN
# std        6.276788    14.432130        NaN      NaN            NaN
# min     2002.000000     1.000000        NaN      NaN            NaN
# 25%     2007.000000    13.000000        NaN      NaN            NaN
# 50%     2012.000000    25.000000        NaN      NaN            NaN
# 75%     2017.000000    38.000000        NaN      NaN            NaN
# max     2023.000000    50.000000        NaN      NaN            NaN
#
#                 lat          lng
# count   1050.000000  1050.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean      35.231239     0.070343
# std       24.690886    61.607445
# min      -38.336369  -122.870051
# 25%       35.824923    -3.737738
# 50%       43.318237     2.351377
# 75%       48.857548    12.568337
# max       63.843390   151.209295

# %% [markdown]
# - **Visualizar las primeras filas del dataframe.**

# %%
# Visualizar las primeras filas del dataframe.
df.head()
# Out:
#    year  rank                restaurant     location         country  \
# 0  2002     1                  El Bulli        Roses           Spain
# 1  2002     2  Restaurant Gordon Ramsay       London  United Kingdom
# 2  2002     3        The French Laundry   Yountville   United States
# 3  2002     4                  Rockpool       Sydney       Australia
# 4  2002     5            Spoon des Iles  Ile Maurice       Mauritius
#
#          lat         lng
# 0  42.263949    3.179553
# 1  51.507218   -0.127586
# 2  38.401578 -122.360810
# 3 -33.868820  151.209295
# 4 -20.348404   57.552152

# %% [markdown]
# - **Hacer una propuesta de análisis o objetivo de análisis que se podria llevar a cabo con el dataset. ¿Que tipo de conclusiones podriamos obtener?**

# %% [markdown]
# _Respuesta:_ top paises, ciudades y continentes en restaurantes en el ranking,

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# Un caso particular de JSON muy utilizados en datos con referencias geográficas son los GEO-JSON. Este tipo de datos tienen un formato JSON donde uno de los campos su la latitud y la longitud (o coordenadas x y y si se utiliza otro sistema de referencia).
#
# En este ejercicio trabajaremos con un dataset utilizado para tener geolocalitzados los centros de salud de la provincia de Alacant. Se pide:
#
# 1. **Cargar el geo-JSON** centros-sanitarios.geojson
# 2. Mostrar el **número de entradas** que hay al JSON
# 3. Extraer las **coordenadas, el tipo de centro (CS_TIPO), el número de camas (CS_CAMAS) y de ucis (CS_UCI)** y guardarlo en un DataFrame.
# 4. Mostrar los tipos de **centro únicos** que hay al DataFrame ("Consultorio", "Ambulatorio", etc).
# 5. Contar **cuántas entradas hay al Dataframe por tipo de centro**.
# 6. **Representar al mapa** los centros que aparecen al JSON e indicar como _tooltip_ el tipo. Utilizar como referencia el ejemplo que se muestra a continuación.
# 7. Repetir la representación anterior pero **modificando el color de los 3 tipos de centro siguientes: 'Centro de salud', 'Consultorio local', 'Hospital general'** (resultados apartado 5).
# 8. Contar **cuantas camas y ucis tiene** Alacant.

# %% [markdown]
# Para hacer la representación en el mapa, se va a utilizar la librería folium, la cual es una librería muy intuitiva de utilizar para hacer pequeñas representacions geograficas (https://python-visualization.github.io/folium/index.html).
#
# La particularidad de esta librería es que las localizaciones deben estar dadas en latitud y longitud. Para este ejercicio ya las tenemos en latitud y longiud, pero de no ser el caso previamente a representar los valores de las coordenadas dadas en el json, se debería hacer una transformación de sistema de referencia. Para ello, se podría utilizar la librería pyproj (https://pypi.org/project/pyproj/). En este ejercicio, de todos modos, no va a ser necesario.

# %% [markdown]
# _Ejemplo representación dos puntos en mapa con folium:_

# %%
## inicialización de las coordenadas (en lat i long)

import warnings
warnings.filterwarnings("ignore")

lon1= -0.376125
lat1= 39.470515

lon2= -0.37513888888889
lat2= 39.475611111111

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (0.17.0)
# Requirement already satisfied: branca>=0.6.0 in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (from folium) (1.24.4)
# Requirement already satisfied: requests in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (from requests->folium) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/juan/.pyenv/versions/3.8.17/lib/python3.8/site-packages (from requests->folium) (2024.8.30)

# %%
# Cargar folium y crear data
import folium

tooltip1='Ajuntament'
tooltip2='Catedral'

m = folium.Map(location=[lat1, lon1])
folium.Marker([lat1, lon1], icon=folium.Icon(color='red'), tooltip=tooltip1).add_to(m)
folium.Marker([lat2, lon2], icon=folium.Icon(color='blue'), tooltip=tooltip2).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1807e4b7b638884a92978e6b7fa0d3bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1807e4b7b638884a92978e6b7fa0d3bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1807e4b7b638884a92978e6b7fa0d3bf = L.map(
#                 &quot;map_1807e4b7b638884a92978e6b7fa0d3bf&quot;,
#                 {
#                     center: [39.470515, -0.376125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43b0576e84db77a9b2fc276dbdff3849 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1807e4b7b638884a92978e6b7fa0d3bf);
#
#
#             var marker_6754df340e4d3670aaba1ffeb3343c96 = L.marker(
#                 [39.470515, -0.376125],
#                 {}
#             ).addTo(map_1807e4b7b638884a92978e6b7fa0d3bf);
#
#
#             var icon_0a3745eea7df1a3c005db7b524c01cba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6754df340e4d3670aaba1ffeb3343c96.setIcon(icon_0a3745eea7df1a3c005db7b524c01cba);
#
#
#             marker_6754df340e4d3670aaba1ffeb3343c96.bindTooltip(
#                 `&lt;div&gt;
#                      Ajuntament
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_539206e629b42303103e30dbfd6ec5b6 = L.marker(
#                 [39.475611111111, -0.37513888888889],
#                 {}
#             ).addTo(map_1807e4b7b638884a92978e6b7fa0d3bf);
#
#
#             var icon_c663129a36fd74fc6db1f54dae18171a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_539206e629b42303103e30dbfd6ec5b6.setIcon(icon_c663129a36fd74fc6db1f54dae18171a);
#
#
#             marker_539206e629b42303103e30dbfd6ec5b6.bindTooltip(
#                 `&lt;div&gt;
#                      Catedral
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Pregunta 1:

# %%
def cargar_geojson(ruta: str) -> dict:
    """Cargar archivo GeoJSON."""
    with open(ruta, 'r') as archivo_geojson:
        return json.load(archivo_geojson)

def contar_entradas_geojson(geojson_data: dict) -> int:
    """Contar el número de entradas en el GeoJSON."""
    return len(geojson_data['features'])

# %%
geojson_data = cargar_geojson(ruta+'/data/centros-sanitarios.geojson')

num_entradas = contar_entradas_geojson(geojson_data)
print(f"Número de entradas en el GeoJSON: {num_entradas}")
# Out:
# Número de entradas en el GeoJSON: 393

# %% [markdown]
# Pregunta 2:

# %%
def extraer_datos_geojson(geojson_data: dict) -> pd.DataFrame:
    """Extraer coordenadas, tipo de centro, camas y ucis y guardarlo en un DataFrame."""
    datos = []
    for feature in geojson_data['features']:
        coordenadas = feature['geometry']['coordinates']
        tipo_centro = feature['properties']['CS_TIPO']
        camas = feature['properties'].get('CS_CAMAS', 0)
        ucis = feature['properties'].get('CS_UCI', 0)
        
        datos.append({
            'Latitud': coordenadas[1],
            'Longitud': coordenadas[0],
            'Tipo': tipo_centro,
            'Camas': camas,
            'UCIs': ucis
        })
    
    return pd.DataFrame(datos)


df_centros = extraer_datos_geojson(geojson_data)

# %%
print(df_centros.head())
# Out:
#     Latitud  Longitud               Tipo Camas UCIs
# 0  38.78054  -0.51644  Consultorio local     0    0
# 1  38.79498  -0.40206  Consultorio local     0    0
# 2  38.67489  -0.33096  Consultorio local     0    0
# 3  38.77306  -0.55562  Consultorio local     0    0
# 4  38.76102  -0.35363  Consultorio local     0    0

# %% [markdown]
# Pregunta 3:

# %%
def mostrar_tipos_centro(df: pd.DataFrame) -> None:
    """Mostrar los tipos de centros únicos."""
    tipos_unicos = df['Tipo'].unique()
    print("Tipos de centros únicos:", tipos_unicos)

mostrar_tipos_centro(df_centros)
# Out:
# Tipos de centros únicos: ['Consultorio local' 'Centro de salud' 'Otros centros sanitarios'
#  'Ambulatorio, centro especialidades o policlínicas' 'Hospital general'
#  'Hospitales otras especialidades' 'Hospital geriátrico y larga estancia'
#  'Hospital psiquiátrico' 'Centros de urgencia y casas de socorro']

# %% [markdown]
# Pregunta 4:

# %%
def contar_centros_por_tipo(df: pd.DataFrame) -> pd.Series:
    """Contar cuántas entradas hay por tipo de centro."""
    return df['Tipo'].value_counts()


centros_por_tipo = contar_centros_por_tipo(df_centros)
print(centros_por_tipo)
# Out:
# Tipo
# Consultorio local                                    175
# Otros centros sanitarios                              91
# Centro de salud                                       85
# Ambulatorio, centro especialidades o policlínicas     16
# Hospital general                                      13
# Hospitales otras especialidades                        7
# Hospital psiquiátrico                                  3
# Hospital geriátrico y larga estancia                   2
# Centros de urgencia y casas de socorro                 1
# Name: count, dtype: int64

# %% [markdown]
# Pregunta 5:

# %%
import folium

def representar_centros_mapa(df: pd.DataFrame) -> folium.Map:
    """Representar los centros en un mapa y mostrar el tipo de centro como tooltip."""
    m = folium.Map(location=[38.3452, -0.481006], zoom_start=10)  # Ubicación en Alacant

    for _, row in df.iterrows():
        folium.Marker(
            [row['Latitud'], row['Longitud']],
            tooltip=row['Tipo']
        ).add_to(m)

    return m


mapa_centros = representar_centros_mapa(df_centros)
mapa_centros
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_452d1aa1075aa0d96b9767fd04be41d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_452d1aa1075aa0d96b9767fd04be41d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_452d1aa1075aa0d96b9767fd04be41d9 = L.map(
#                 &quot;map_452d1aa1075aa0d96b9767fd04be41d9&quot;,
#                 {
#                     center: [38.3452, -0.481006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac4c774890fc19c2ab7a4e64f265887d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_452d1aa1075aa0d96b9767fd04be41d9);
#
#
#             var marker_acaa3820826836af2aff80cfd88eb294 = L.marker(
#                 [38.78054, -0.51644],
#                 {}
#             ).addTo(map_452d1aa1075aa0d96b9767fd04be41d9);
#
#
#             marker_acaa3820826836af2aff80cfd88eb294.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0c0e02d26d57bfd6e7bab81ac193ef9e = L.marker(
#                 [38.79498, -0.40206],
#                 {}
#             ).addTo(map_452d1aa1075aa0d96b9767fd04be41d9);
#
#
#             marker_0c0e02d26d57bfd6e7bab81ac193ef9e.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eda429e0e9cdfb35066e48a00bbf1549 = L.marker(
#                 [38.67489, -0.33096],
#                 {}
#             ).addTo(map_452d1aa1075aa0d96b9767fd04be41d9);
#
#
#             marker_eda429e0e9cdfb35066e48a00bbf1549.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_34509942eef3d0bdc0b9361083ac3046 = L.marker(
#                 [38.77306, -0.55562],
#                 {}
#             ).addTo(map_452d1aa1075aa0d96b9767fd04be41d9);
#
#
#             marker_34509942eef3d0bdc0b9361083ac3046.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_20b027a0373c1cb48869698f95689dba = L.marker(
#                 [38.76102, -0.35363],
#                 {}
#             ).addTo(map_452d1aa1075aa0d96b9767fd04be41d9);
#
#
#             marker_20b027a0373c1cb48869698f95689dba.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1153ea9811342db596a894bef7dc61f7 = L.marker(
#                 [38.77233, -0.42485],
#                 {}
#             ).addTo(map_452d1aa1075aa0d96b9767fd04be41d9);
#
#
#             marker_1153ea9811342db596a894bef7dc61f7.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f01d0e57d5cde3b5a1e12a2fd67fa9f0 = L.marker(
#                 [38.7365, -0.34181],
#                 {}
#             ).addTo(map_452d1aa1075aa0d96b9767fd04be41d9);
#
#
#             marker_f01d0e57d5cde3b5a1e12a2fd67fa9f0.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_39e83317276d52cea8fcd5783d170ba3 = L.marker(
#                 [38.69053, -0.34325],
#                 {}
#             ).addTo(map_452d1aa1075aa0d96b9767fd04be41d9);
#
#
#             marker_39e83317276d52cea8fcd5783d170ba3.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c798810a11fc6363c5871ef8e382ae61 = L.marker(
#                 [38.8192, -0.3774],
#                 {}
#             ).addTo(map_452d1aa1075aa0d96b9767fd04be41d9);
#
#
#             marker_c798810a11fc6363c5871ef8e382ae61.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1592e1c0704594031eb502e85043344b = L.marker(
#                 [38.77691, -0.38988],
#                 {}
#             ).addTo(map_452d1aa1075aa0d96b9767fd0

# %% [markdown]
# Pregunta 6:

# %%
def representar_centros_con_color(df: pd.DataFrame) -> folium.Map:
    """Representar los centros en un mapa modificando el color según el tipo."""
    m = folium.Map(location=[38.3452, -0.481006], zoom_start=10)

    colores = {
        'Centro de salud': 'red',
        'Consultorio local': 'blue',
        'Hospital general': 'green'
    }

    for _, row in df.iterrows():
        color = colores.get(row['Tipo'])#, 'yellow')  
        folium.Marker(
            [row['Latitud'], row['Longitud']],
            icon=folium.Icon(color=color),
            tooltip=row['Tipo']
        ).add_to(m)

    return m


mapa_centros_colores = representar_centros_con_color(df_centros)
mapa_centros_colores
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_095a86af9fa75b8cedee39295d2e6e59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_095a86af9fa75b8cedee39295d2e6e59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_095a86af9fa75b8cedee39295d2e6e59 = L.map(
#                 &quot;map_095a86af9fa75b8cedee39295d2e6e59&quot;,
#                 {
#                     center: [38.3452, -0.481006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_169e6789242040e5e57084ade211c90b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_095a86af9fa75b8cedee39295d2e6e59);
#
#
#             var marker_230fd832c0c2f8e4028b6e8d0a6349d7 = L.marker(
#                 [38.78054, -0.51644],
#                 {}
#             ).addTo(map_095a86af9fa75b8cedee39295d2e6e59);
#
#
#             var icon_721a84f3099c68508f53a43b9a0525e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_230fd832c0c2f8e4028b6e8d0a6349d7.setIcon(icon_721a84f3099c68508f53a43b9a0525e2);
#
#
#             marker_230fd832c0c2f8e4028b6e8d0a6349d7.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6985ea9d3bf64c304ffe8bfb905977cd = L.marker(
#                 [38.79498, -0.40206],
#                 {}
#             ).addTo(map_095a86af9fa75b8cedee39295d2e6e59);
#
#
#             var icon_ebedf59f5b345fa4f87d6b569fa11b9f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6985ea9d3bf64c304ffe8bfb905977cd.setIcon(icon_ebedf59f5b345fa4f87d6b569fa11b9f);
#
#
#             marker_6985ea9d3bf64c304ffe8bfb905977cd.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4aca1d99a6d1fba85c25f19c61b49c3f = L.marker(
#                 [38.67489, -0.33096],
#                 {}
#             ).addTo(map_095a86af9fa75b8cedee39295d2e6e59);
#
#
#             var icon_700371aaf937b419065d8f5975909ff9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4aca1d99a6d1fba85c25f19c61b49c3f.setIcon(icon_700371aaf937b419065d8f5975909ff9);
#
#
#             marker_4aca1d99a6d1fba85c25f19c61b49c3f.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_741aa631aff043e4f0ed61eebf2ad926 = L.marker(
#                 [38.77306, -0.55562],
#                 {}
#             ).addTo(map_095a86af9fa75b8cedee39295d2e6e59);
#
#
#             var icon_4ece7849751af7e03b3766f6141fd2c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_741aa631aff043e4f0ed61eebf2ad926.setIcon(icon_4ece7849751af7e03b3766f6141fd2c7);
#
#
#             marker_741aa631aff043e4f0ed61eebf2ad926.bindTooltip(
#                 `&lt;div&gt;
#                      Consultorio local
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0d03ed35c4c51053c1481d6b5b334376 = L.marker(
#                 [38.76102, -0.35363],
#                 {}
#             ).addTo(map_095a86af9fa75b8cedee39295d2e6e59);
#
#
#             var icon_2e4b9fb18294a4373cb0905bfed20ab9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0d03ed35c4c51053c1

# %% [markdown]
# Pregunta 7:

# %%
def contar_camas_uci(df: pd.DataFrame) -> None:
    """Contar el número total de camas y UCIs en Alacant."""
    df['Camas'] = pd.to_numeric(df['Camas'], errors='coerce').fillna(0)
    df['UCIs'] = pd.to_numeric(df['UCIs'], errors='coerce').fillna(0)

    print(f"Total camas en Alacant: {df['Camas'].sum()}")
    print(f"Total UCIs en Alacant: {df['UCIs'].sum()}")

contar_camas_uci(df_centros)
# Out:
# Total camas en Alacant: 5993.0
# Total UCIs en Alacant: 21

# %% [markdown]
# ---
